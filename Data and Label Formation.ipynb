# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Expression images formation

# %% [markdown]
# ## LUAD

# %%
# %%time
#load all the gene expression data
gse72904_exp=pd.read_hdf('data/LUAD/gse72904.h5',key='gene_expression')
consortium_exp=pd.read_hdf('data/LUAD/consortium.h5',key='gene_expression')
gse41271_exp=pd.read_hdf('data/LUAD/gse41271.h5',key='gene_expression')
gse31210_exp=pd.read_hdf('data/LUAD/gse31210.h5',key='gene_expression')
pnas_exp=pd.read_hdf('data/LUAD/pnas.h5',key='gene_expression')
gse11969_exp=pd.read_hdf('data/LUAD/gse11969.h5',key='gene_expression')
gse20853_exp=pd.read_hdf('data/LUAD/gse20853.h5',key='gene_expression')
gse13213_exp=pd.read_hdf('data/LUAD/gse13213.h5',key='gene_expression')
gse32863_exp=pd.read_hdf('data/LUAD/gse32863.h5',key='gene_expression')
gse26939_exp=pd.read_hdf('data/LUAD/gse26939.h5',key='gene_expression')
gse10072_exp=pd.read_hdf('data/LUAD/gse10072.h5',key='gene_expression')
gse12667_exp=pd.read_hdf('data/LUAD/gse12667.h5',key='gene_expression')
gse1037_2088_exp=pd.read_hdf('data/LUAD/gse1037&2088.h5',key='gene_expression')
gse29016_exp=pd.read_hdf('data/LUAD/gse29016.h5',key='gene_expression')
nm_exp=pd.read_hdf('data/LUAD/nm.h5',key='gene_expression')
gse5843_exp=pd.read_hdf('data/LUAD/gse5843.h5',key='gene_expression')
gse20875_exp=pd.read_hdf('data/LUAD/gse20875.h5',key='gene_expression')
gse2514_exp=pd.read_hdf('data/LUAD/gse2514.h5',key='gene_expression')
gse17475_exp=pd.read_hdf('data/LUAD/gse17475.h5',key='gene_expression')
tcga_luad_exp=pd.read_hdf('data/LUAD/tcga_luad.h5',key='gene_expression')
# Out:
# CPU times: total: 156 ms
# Wall time: 126 ms

# %%
# %%time
#load all the clinical data
gse72904_clinical=pd.read_hdf('data/LUAD/gse72904.h5',key='clinical')
consortium_clinical=pd.read_hdf('data/LUAD/consortium.h5',key='clinical')
gse41271_clinical=pd.read_hdf('data/LUAD/gse41271.h5',key='clinical')
gse31210_clinical=pd.read_hdf('data/LUAD/gse31210.h5',key='clinical')
pnas_clinical=pd.read_hdf('data/LUAD/pnas.h5',key='clinical')
gse11969_clinical=pd.read_hdf('data/LUAD/gse11969.h5',key='clinical')
gse20853_clinical=pd.read_hdf('data/LUAD/gse20853.h5',key='clinical')
gse13213_clinical=pd.read_hdf('data/LUAD/gse13213.h5',key='clinical')
gse32863_clinical=pd.read_hdf('data/LUAD/gse32863.h5',key='clinical')
gse26939_clinical=pd.read_hdf('data/LUAD/gse26939.h5',key='clinical')
gse10072_clinical=pd.read_hdf('data/LUAD/gse10072.h5',key='clinical')
gse12667_clinical=pd.read_hdf('data/LUAD/gse12667.h5',key='clinical')
gse1037_2088_clinical=pd.read_hdf('data/LUAD/gse1037&2088.h5',key='clinical')
gse29016_clinical=pd.read_hdf('data/LUAD/gse29016.h5',key='clinical')
nm_clinical=pd.read_hdf('data/LUAD/nm.h5',key='clinical')
gse5843_clinical=pd.read_hdf('data/LUAD/gse5843.h5',key='clinical')
gse20875_clinical=pd.read_hdf('data/LUAD/gse20875.h5',key='clinical')
gse2514_clinical=pd.read_hdf('data/LUAD/gse2514.h5',key='clinical')
gse17475_clinical=pd.read_hdf('data/LUAD/gse17475.h5',key='clinical')
tcga_luad_clinical=pd.read_hdf('data/LUAD/tcga_luad.h5',key='clinical')
# Out:
# CPU times: total: 93.8 ms
# Wall time: 106 ms

# %%
luad_test_exp=pd.read_hdf('data/LUAD/test_set.h5',key='gene_expression')
luad_test_clinical=pd.read_hdf('data/LUAD/test_set.h5',key='clinical')

# %% [markdown]
# ## NSCLC

# %%
# %%time
#load all the gene expression data
gse1987_exp=pd.read_hdf('data/NSCLC/gse1987.h5',key='gene_expression')
gse4573_exp=pd.read_hdf('data/NSCLC/gse4573.h5',key='gene_expression')
gse8894_exp=pd.read_hdf('data/NSCLC/gse8894.h5',key='gene_expression')
gse9971_exp=pd.read_hdf('data/NSCLC/gse9971.h5',key='gene_expression')
gse10245_exp=pd.read_hdf('data/NSCLC/gse10245.h5',key='gene_expression')
gse11117_exp=pd.read_hdf('data/NSCLC/gse11117.h5',key='gene_expression')
gse14814_exp=pd.read_hdf('data/NSCLC/gse14814.h5',key='gene_expression')
gse16534_exp=pd.read_hdf('data/NSCLC/gse16534.h5',key='gene_expression')
gse18842_exp=pd.read_hdf('data/NSCLC/gse18842.h5',key='gene_expression')
gse19188_exp=pd.read_hdf('data/NSCLC/gse19188.h5',key='gene_expression')
gse19804_exp=pd.read_hdf('data/NSCLC/gse19804.h5',key='gene_expression')
gse25326_exp=pd.read_hdf('data/NSCLC/gse25326.h5',key='gene_expression')
gse28571_exp=pd.read_hdf('data/NSCLC/gse28571.h5',key='gene_expression')
gse37745_exp=pd.read_hdf('data/NSCLC/gse37745.h5',key='gene_expression')
gse42127_exp=pd.read_hdf('data/NSCLC/gse42127.h5',key='gene_expression')
gse43458_exp=pd.read_hdf('data/NSCLC/gse43458.h5',key='gene_expression')
gse50081_exp=pd.read_hdf('data/NSCLC/gse50081.h5',key='gene_expression')
# Out:
# CPU times: total: 78.1 ms
# Wall time: 88.1 ms

# %%
# %%time

gse1987_clinical=pd.read_hdf('data/NSCLC/gse1987.h5',key='clinical')
gse4573_clinical=pd.read_hdf('data/NSCLC/gse4573.h5',key='clinical')
gse8894_clinical=pd.read_hdf('data/NSCLC/gse8894.h5',key='clinical')
gse9971_clinical=pd.read_hdf('data/NSCLC/gse9971.h5',key='clinical')
gse10245_clinical=pd.read_hdf('data/NSCLC/gse10245.h5',key='clinical')
gse11117_clinical=pd.read_hdf('data/NSCLC/gse11117.h5',key='clinical')
gse14814_clinical=pd.read_hdf('data/NSCLC/gse14814.h5',key='clinical')
gse16534_clinical=pd.read_hdf('data/NSCLC/gse16534.h5',key='clinical')
gse18842_clinical=pd.read_hdf('data/NSCLC/gse18842.h5',key='clinical')
gse19188_clinical=pd.read_hdf('data/NSCLC/gse19188.h5',key='clinical')
gse19804_clinical=pd.read_hdf('data/NSCLC/gse19804.h5',key='clinical')
gse25326_clinical=pd.read_hdf('data/NSCLC/gse25326.h5',key='clinical')
gse28571_clinical=pd.read_hdf('data/NSCLC/gse28571.h5',key='clinical')
gse37745_clinical=pd.read_hdf('data/NSCLC/gse37745.h5',key='clinical')
gse42127_clinical=pd.read_hdf('data/NSCLC/gse42127.h5',key='clinical')
gse43458_clinical=pd.read_hdf('data/NSCLC/gse43458.h5',key='clinical')
gse50081_clinical=pd.read_hdf('data/NSCLC/gse50081.h5',key='clinical')
# Out:
# CPU times: total: 78.1 ms
# Wall time: 88 ms

# %% [markdown]
# ## LUSC

# %%
# %%time
#load all the gene expression data
gse5828_exp=pd.read_hdf('data/LUSC/gse5828.h5',key='gene_expression')
gse12472_exp=pd.read_hdf('data/LUSC/gse12472.h5',key='gene_expression')
gse17710_exp=pd.read_hdf('data/LUSC/gse17710.h5',key='gene_expression')
gse23822_exp=pd.read_hdf('data/LUSC/gse23822.h5',key='gene_expression')
gse74777_exp=pd.read_hdf('data/LUSC/gse74777.h5',key='gene_expression')
tcga_lusc_exp=pd.read_hdf('data/LUSC/tcga_lusc.h5',key='gene_expression')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 32 ms

# %%
# %%time

gse5828_clinical=pd.read_hdf('data/LUSC/gse5828.h5',key='clinical')
gse12472_clinical=pd.read_hdf('data/LUSC/gse12472.h5',key='clinical')
gse17710_clinical=pd.read_hdf('data/LUSC/gse17710.h5',key='clinical')
gse23822_clinical=pd.read_hdf('data/LUSC/gse23822.h5',key='clinical')
gse74777_clinical=pd.read_hdf('data/LUSC/gse74777.h5',key='clinical')
tcga_lusc_clinical=pd.read_hdf('data/LUSC/tcga_lusc.h5',key='clinical')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 34 ms

# %%
len(gse74777_clinical)
# Out:
# 107

# %% [markdown]
# ## SKCM

# %%
skcm_exp_train=pd.read_hdf('data/SKCM/train_set.h5',key='gene_expression')
skcm_exp_test=pd.read_hdf('data/SKCM/test_set.h5',key='gene_expression')

# %%
skcm_clinical_train=pd.read_hdf('data/SKCM/train_set.h5',key='clinical')
skcm_clinical_test=pd.read_hdf('data/SKCM/test_set.h5',key='clinical')

# %% [markdown]
# ## LGG

# %%
lgg_exp_train=pd.read_hdf('data/LGG/train_set.h5',key='gene_expression')
lgg_exp_test=pd.read_hdf('data/LGG/test_set.h5',key='gene_expression')

# %%
lgg_clinical_train=pd.read_hdf('data/LGG/train_set.h5',key='clinical')
lgg_clinical_test=pd.read_hdf('data/LGG/test_set.h5',key='clinical')

# %% [markdown]
# ## Pathways

# %%
pathways=pd.read_csv('D:/MyData/Pathway_Attention/data/All_Sub-pathways/allPathways.csv',sep='\,',engine='python',header=None,index_col=0)

# %%
pathways
# Out:
#                                             1       2       3        4   \
# 0
# Androgen_receptor_signaling_pathway         AR    KLK3     NaN      NaN
# Cytokine-Jak-STAT_signaling_pathway        IL2     IL3     IL4      IL5
# DCC-apoptotic_pathway                    CASP3     DCC   CASP9    APPL1
# EGF-EGFR-PI3K_signaling_pathway            EGF    EGFR  PIK3CA   PIK3CB
# EGF-EGFR-PLCG-CAMK_signaling_pathway       EGF    EGFR   PLCG1    PLCG2
# EGF-EGFR-RAS-ERK_signaling_pathway         EGF    EGFR    GRB2     SOS1
# EGF-EGFR-RAS-RalGDS_signaling_pathway      EGF    EGFR    GRB2     SOS1
# EGF-EGFR-RAS-RASSF1_signaling_pathway      EGF    EGFR    GRB2     SOS1
# EGF-ERBB2-RAS-ERK_signaling_pathway        EGF   ERBB2    EGFR     GRB2
# EGF-Jak-STAT_signaling_pathway             EGF    EGFR    JAK1    STAT1
# FGF-FGFR-PI3K_signaling_pathway           FGF1    FGF2    FGF3     FGF4
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF1    FGF2    FGF3     FGF4
# FLT3LG-FLT3-RAS-ERK_signaling_pathway   FLT3LG    FLT3    GRB2     SOS1
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway  FLT3LG    FLT3    GRB2     SOS1
# FLT3LG-FLT3-STAT5_signaling_pathway     FLT3LG    FLT3  STAT5A   STAT5B
# Hedgehog_signaling_pathway                 SHH   PTCH1     SMO     SUFU
# HGF-MET-PI3K_signaling_pathway             HGF     MET    GAB1   PIK3CA
# HGF-MET-RAS-ERK_signaling_pathway          HGF     MET    GRB2     SOS1
# HIF-1_signaling_pathway                  HIF1A    ARNT  SLC2A1    VEGFA
# IGF2-IGF1R-PI3K_signaling_pathway         IGF1    IGF2   IGF1R     GRB2
# IGF-IGF1R-RAS-ERK_signaling_pathway       IGF2   IGF1R  PIK3CA   PIK3CB
# Intrinsic_apoptotic_pathway             PMAIP1    BBC3     BAD  BCL2L11
# KEAP1-NRF2_signaling_pathway             KEAP1  NFE2L2   HMOX1     NQO1
# KITLG-KIT-PI3K_signaling_pathway         KITLG     KIT  PIK3CA   PIK3CB
# KITLG-KIT-RAS-ERK_signaling_pathway      KITLG     KIT    GRB2     SOS1
# MDM2-p21-Cell_cycle_G1-S                CDKN2A    MDM2    TP53   CDKN1A
# NOTCH_signaling_pathway                   DLL1    DLL3    DLL4     JAG1
# p15-Cell_cycle_G1-S                        MYC     MAX  ZBTB17   CDKN2B
# p16-Cell_cycle_G1-S                     CDKN2A   CCND1   CCND2    CCND3
# p27-Cell_cycle_G1-S                       SKP1    CUL1    RBX1     SKP2
# PDGF-PDGFR-PI3K_signaling_pathway        PDGFA   PDGFB  PDGFRA   PDGFRB
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   PDGFA   PDGFB  PDGFRA   PDGFRB
# PDGF-PDGFR-RAS-ERK_signaling_pathway     PDGFA   PDGFB  PDGFRA   PDGFRB
# PTEN-PIP3-AKT_signaling_pathway           PTEN    AKT1    AKT2     AKT3
# Telomerase_activity                       TERC     NaN     NaN      NaN
# TGFA-EGFR-PI3K_signaling_pathway         TGFB1   TGFB2   TGFB3   TGFBR2
# TGFA-EGFR-PLCG-PKC_signaling_pathway      TGFA    EGFR  PIK3CA   PIK3CB
# TGFA-EGFR-RAS-ERK_signaling_pathway       TGFA    EGFR   PLCG1    PLCG2
# TGF-beta_signaling_pathway                TGFA    EGFR    GRB2     SOS1
# WNT_signaling_pathway                     WNT1    WNT2   WNT2B     WNT3
# NaN                                               NaN     NaN      NaN
#
#                                             5       6       7       8   \
# 0
# Androgen_receptor_signaling_pathway        NaN     NaN     NaN     NaN
# Cytokine-Jak-STAT_signaling_pathway        IL6     IL7   IL12A   IL12B
# DCC-apoptotic_pathway                      NaN     NaN     NaN     NaN
# EGF-EGFR-PI3K_signaling_pathway         PIK3CD    AKT1    AKT2    AKT3
# EGF-EGFR-PLCG-CAMK_signaling_pathway     CALM1   CALM2   CALM3   CAMK1
# EGF-EGFR-RAS-ERK_signaling_pathway        SOS2    HRAS    KRAS    NRAS
# EGF-EGFR-RAS-RalGDS_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# EGF-EGFR-RAS-RASSF1_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# EGF-ERBB2-RAS-ERK_signaling_pathway       SOS1    SOS2    HRAS    KRAS
# EGF-Jak-STAT_signaling_pathway           STAT3  STAT5A  STAT5B     NaN
# FGF-FGFR-PI3K_signaling_pathway           FGF5    FGF6    FGF7    FGF8
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF5    FGF6    FGF7    FGF8
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway    SOS2    HRAS    KRAS    NRAS
# FLT3LG-FLT3-STAT5_signaling_pathway        NaN     NaN     NaN     NaN
# Hedgehog_signaling_pathway                GLI1    GLI2    GLI3    GLI1
# HGF-MET-PI3K_signaling_pathway          PIK3CB  PIK3CD    AKT1    AKT2
# HGF-MET-RAS-ERK_signaling_pathway         SOS2    HRAS    KRAS    NRAS
# HIF-1_signaling_pathway                  TGFB1   TGFB2   TGFB3   PDGFB
# IGF2-IGF1R-PI3K_signaling_pathway         SOS1    SOS2    HRAS    KRAS
# IGF-IGF1R-RAS-ERK_signaling_pathway     PIK3CD    AKT1    AKT2    AKT3
# Intrinsic_apoptotic_pathway               BCL2  BCL2L1     BAX    BAK1
# KEAP1-NRF2_signaling_pathway             GSTO2   GSTA5   GSTA1   GSTA2
# KITLG-KIT-PI3K_signaling_pathway        PIK3CD    AKT1    AKT2    AKT3
# KITLG-KIT-RAS-ERK_signaling_pathway       SOS2    HRAS    KRAS    NRAS
# MDM2-p21-Cell_cycle_G1-S                 CCND1   CCND2   CCND3    CDK4
# NOTCH_signaling_pathway                   JAG2  NOTCH1  NOTCH2  NOTCH3
# p15-Cell_cycle_G1-S                      CCND1   CCND2   CCND3    CDK4
# p16-Cell_cycle_G1-S                       CDK4    CDK6     RB1    E2F1
# p27-Cell_cycle_G1-S                     CDKN1B   CCNA2   CCNA1   CCNE1
# PDGF-PDGFR-PI3K_signaling_pathway       PIK3CA  PIK3CB  PIK3CD    AKT1
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   PLCG1   PLCG2   CALM1   CALM2
# PDGF-PDGFR-RAS-ERK_signaling_pathway      GRB2    SOS1    SOS2    HRAS
# PTEN-PIP3-AKT_signaling_pathway            NaN     NaN     NaN     NaN
# Telomerase_activity                        NaN     NaN     NaN     NaN
# TGFA-EGFR-PI3K_signaling_pathway        TGFBR1   SMAD2   SMAD3   SMAD4
# TGFA-EGFR-PLCG-PKC_signaling_pathway    PIK3CD    AKT1    AKT2    AKT3
# TGFA-EGFR-RAS-ERK_signaling_pathway      PRKCA   PRKCB   PRKCG    ELK1
# TGF-beta_signaling_pathway                SOS2    HRAS    KRAS    NRAS
# WNT_signaling_pathway                    WNT3A    WNT4   WNT5A   WNT5B
# NaN                                        NaN     NaN     NaN     NaN
#
#                                             9        10  ...     37     38  \
# 0                                                        ...
# Androgen_receptor_signaling_pathway        NaN      NaN  ...    NaN    NaN
# Cytokine-Jak-STAT_signaling_pathway       IL13     IL15  ...   JAK3  STAT1
# DCC-apoptotic_pathway                      NaN      NaN  ...    NaN    NaN
# EGF-EGFR-PI3K_signaling_pathway            BAD      NaN  ...    NaN    NaN
# EGF-EGFR-PLCG-CAMK_signaling_pathway    CAMK1D   CAMK1G  ...    NaN    NaN
# EGF-EGFR-RAS-ERK_signaling_pathway        ARAF     BRAF  ...    NaN    NaN
# EGF-EGFR-RAS-RalGDS_signaling_pathway   RALGDS     RALA  ...    NaN    NaN
# EGF-EGFR-RAS-RASSF1_signaling_pathway   RASSF1   RASSF5  ...    NaN    NaN
# EGF-ERBB2-RAS-ERK_signaling_pathway       NRAS     ARAF  ...    NaN    NaN
# EGF-Jak-STAT_signaling_pathway             NaN      NaN  ...    NaN    NaN
# FGF-FGFR-PI3K_signaling_pathway           FGF9    FGF10  ...    NaN    NaN
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF9    FGF10  ...    NaN    NaN
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     ARAF     BRAF  ...    NaN    NaN
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway  PIK3CA   PIK3CB  ...    NaN    NaN
# FLT3LG-FLT3-STAT5_signaling_pathway        NaN      NaN  ...    NaN    NaN
# Hedgehog_signaling_pathway               PTCH1    PTCH2  ...    NaN    NaN
# HGF-MET-PI3K_signaling_pathway            AKT3      BAD  ...    NaN    NaN
# HGF-MET-RAS-ERK_signaling_pathway         ARAF     BRAF  ...    NaN    NaN
# HIF-1_signaling_pathway                   TGFA      NaN  ...    NaN    NaN
# IGF2-IGF1R-PI3K_signaling_pathway         NRAS     ARAF  ...    NaN    NaN
# IGF-IGF1R-RAS-ERK_signaling_pathway       MTOR  RPS6KB1  ...    NaN    NaN
# Intrinsic_apoptotic_pathway               CYCS    APAF1  ...    NaN    NaN
# KEAP1-NRF2_signaling_pathway             GSTA3    GSTA4  ...    NaN    NaN
# KITLG-KIT-PI3K_signaling_pathway          MTOR  RPS6KB1  ...    NaN    NaN
# KITLG-KIT-RAS-ERK_signaling_pathway       ARAF     BRAF  ...    NaN    NaN
# MDM2-p21-Cell_cycle_G1-S                  CDK6      RB1  ...    NaN    NaN
# NOTCH_signaling_pathway                 NOTCH4     HES1  ...    NaN    NaN
# p15-Cell_cycle_G1-S                       CDK6      RB1  ...    NaN    NaN
# p16-Cell_cycle_G1-S                       E2F2     E2F3  ...    NaN    NaN
# p27-Cell_cycle_G1-S                      CCNE2     CDK2  ...    NaN    NaN
# PDGF-PDGFR-PI3K_signaling_pathway         AKT2     AKT3  ...    NaN    NaN
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   CALM3    CAMK1  ...    NaN    NaN
# PDGF-PDGFR-RAS-ERK_signaling_pathway      KRAS     NRAS  ...    NaN    NaN
# PTEN-PIP3-AKT_signaling_pathway            NaN      NaN  ...    NaN    NaN
# Telomerase_activity                        NaN      NaN  ...    NaN    NaN
# TGFA-EGFR-PI3K_signaling_pathway           NaN      NaN  ...    NaN    NaN
# TGFA-EGFR-PLCG-PKC_signaling_pathway      MTOR      NaN  ...    NaN    NaN
# TGFA-EGFR-RAS-ERK_signaling_pathway        NaN      NaN  ...    NaN    NaN
# TGF-beta_signaling_pathway                ARAF     BRAF  ...    NaN    NaN
# WNT_signaling_pathway                     WNT6    WNT7A  ...  AXIN1  AXIN2
# NaN                                        NaN      NaN  ...    NaN    NaN
#
#                                            39      40     41      42      43  \
# 0
# Androgen_receptor_signaling_pathway       NaN     NaN    NaN     NaN     NaN
# Cytokine-Jak-STAT_signaling_pathway     STAT2   STAT3  STAT4  STAT5A  STAT5B
# DCC-apoptotic_pathway                     NaN     NaN    NaN     NaN     NaN
# EGF-EGFR-PI3K_signaling_pathway           NaN     NaN    NaN     NaN     NaN
# EGF-EGFR-PLCG-CAMK_signaling_pathway      NaN     NaN    NaN     NaN     NaN
# EGF-EGFR-RAS-ERK_signaling_pathway        NaN     NaN    NaN     NaN     NaN
# EGF-EGFR-RAS-RalGDS_signaling_pathway     NaN     NaN    NaN     NaN     NaN
# EGF-EGFR-RAS-RASSF1_signaling_pathway     NaN     NaN    NaN     NaN     NaN
# EGF-ERBB2-RAS-ERK_signaling_pathway       NaN     NaN    NaN     NaN     NaN
# EGF-Jak-STAT_signaling_pathway            NaN     NaN    NaN     NaN     NaN
# FGF-FGFR-PI3K_signaling_pathway           NaN     NaN    NaN     NaN     NaN
# FGF-FGFR-RAS-ERK_signaling_pathway        NaN     NaN    NaN     NaN     NaN
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     NaN     NaN    NaN     NaN     NaN
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway    NaN     NaN    NaN     NaN     NaN
# FLT3LG-FLT3-STAT5_signaling_pathway       NaN     NaN    NaN     NaN     NaN
# Hedgehog_signaling_pathway                NaN     NaN    NaN     NaN     NaN
# HGF-MET-PI3K_signaling_pathway            NaN     NaN    NaN     NaN     NaN
# HGF-MET-RAS-ERK_signaling_pathway         NaN     NaN    NaN     NaN     NaN
# HIF-1_signaling_pathway                   NaN     NaN    NaN     NaN     NaN
# IGF2-IGF1R-PI3K_signaling_pathway         NaN     NaN    NaN     NaN     NaN
# IGF-IGF1R-RAS-ERK_signaling_pathway       NaN     NaN    NaN     NaN     NaN
# Intrinsic_apoptotic_pathway               NaN     NaN    NaN     NaN     NaN
# KEAP1-NRF2_signaling_pathway              NaN     NaN    NaN     NaN     NaN
# KITLG-KIT-PI3K_signaling_pathway          NaN     NaN    NaN     NaN     NaN
# KITLG-KIT-RAS-ERK_signaling_pathway       NaN     NaN    NaN     NaN     NaN
# MDM2-p21-Cell_cycle_G1-S                  NaN     NaN    NaN     NaN     NaN
# NOTCH_signaling_pathway                   NaN     NaN    NaN     NaN     NaN
# p15-Cell_cycle_G1-S                       NaN     NaN    NaN     NaN     NaN
# p16-Cell_cycle_G1-S                       NaN     NaN    NaN     NaN     NaN
# p27-Cell_cycle_G1-S                       NaN     NaN    NaN     NaN     NaN
# PDGF-PDGFR-PI3K_signaling_pathway         NaN     NaN    NaN     NaN     NaN
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway    NaN     NaN    NaN     NaN     NaN
# PDGF-PDGFR-RAS-ERK_signaling_pathway      NaN     NaN    NaN     NaN     NaN
# PTEN-PIP3-AKT_signaling_pathway           NaN     NaN    NaN     NaN     NaN
# Telomerase_activity                       NaN     NaN    NaN     NaN     NaN
# TGFA-EGFR-PI3K_signaling_pathway          NaN     NaN    NaN     NaN     NaN
# TGFA-EGFR-PLCG-PKC_signaling_pathway      NaN     NaN    NaN     NaN     NaN
# TGFA-EGFR-RAS-ERK_signaling_pathway       NaN     NaN    NaN     NaN     NaN
# TGF-beta_signaling_pathway                NaN     NaN    NaN     NaN     NaN
# WNT_signaling_pathway                     APC  CTNNB1   TCF7  TCF7L1  TCF7L2
# NaN                                       NaN     NaN    NaN     NaN     NaN
#
#                                            44    45     46
# 0
# Androgen_receptor_signaling_pathway       NaN   NaN    NaN
# Cytokine-Jak-STAT_signaling_pathway     STAT6  PIM1    NaN
# DCC-apoptotic_pathway                     NaN   NaN    NaN
# EGF-EGFR-PI3K_signaling_pathway           NaN   NaN    NaN
# EGF-EGFR-PLCG-CAMK_signaling_pathway      NaN   NaN    NaN
# EGF-EGFR-RAS-ERK_signaling_pathway        NaN   NaN    NaN
# EGF-EGFR-RAS-RalGDS_signaling_pathway     NaN   NaN    NaN
# EGF-EGFR-RAS-RASSF1_signaling_pathway     NaN   NaN    NaN
# EGF-ERBB2-RAS-ERK_signaling_pathway       NaN   NaN    NaN
# EGF-Jak-STAT_signaling_pathway            NaN   NaN    NaN
# FGF-FGFR-PI3K_signaling_pathway           NaN   NaN    NaN
# FGF-FGFR-RAS-ERK_signaling_pathway        NaN   NaN    NaN
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     NaN   NaN    NaN
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway    NaN   NaN    NaN
# FLT3LG-FLT3-STAT5_signaling_pathway       NaN   NaN    NaN
# Hedgehog_signaling_pathway                NaN   NaN    NaN
# HGF-MET-PI3K_signaling_pathway            NaN   NaN    NaN
# HGF-MET-RAS-ERK_signaling_pathway         NaN   NaN    NaN
# HIF-1_signaling_pathway                   NaN   NaN    NaN
# IGF2-IGF1R-PI3K_signaling_pathway         NaN   NaN    NaN
# IGF-IGF1R-RAS-ERK_signaling_pathway       NaN   NaN    NaN
# Intrinsic_apoptotic_pathway               NaN   NaN    NaN
# KEAP1-NRF2_signaling_pathway              NaN   NaN    NaN
# KITLG-KIT-PI3K_signaling_pathway          NaN   NaN    NaN
# KITLG-KIT-RAS-ERK_signaling_pathway       NaN   NaN    NaN
# MDM2-p21-Cell_cycle_G1-S                  NaN   NaN    NaN
# NOTCH_signaling_pathway                   NaN   NaN    NaN
# p15-Cell_cycle_G1-S                       NaN   NaN    NaN
# p16-Cell_cycle_G1-S                       NaN   NaN    NaN
# p27-Cell_cycle_G1-S                       NaN   NaN    NaN
# PDGF-PDGFR-PI3K_signaling_pathway         NaN   NaN    NaN
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway    NaN   NaN    NaN
# PDGF-PDGFR-RAS-ERK_signaling_pathway      NaN   NaN    NaN
# PTEN-PIP3-AKT_signaling_pathway           NaN   NaN    NaN
# Telomerase_activity                       NaN   NaN    NaN
# TGFA-EGFR-PI3K_signaling_pathway          NaN   NaN    NaN
# TGFA-EGFR-PLCG-PKC_signaling_pathway      NaN   NaN    NaN
# TGFA-EGFR-RAS-ERK_signaling_pathway       NaN   NaN    NaN
# TGF-beta_signaling_pathway                NaN   NaN    NaN
# WNT_signaling_pathway                    LEF1   MYC  CCND1
# NaN                                       NaN   NaN    NaN
#
# [41 rows x 46 columns]

# %%
pathways=pathways.fillna(0)
pathways
# Out:
#                                             1       2       3        4   \
# 0
# Androgen_receptor_signaling_pathway         AR    KLK3       0        0
# Cytokine-Jak-STAT_signaling_pathway        IL2     IL3     IL4      IL5
# DCC-apoptotic_pathway                    CASP3     DCC   CASP9    APPL1
# EGF-EGFR-PI3K_signaling_pathway            EGF    EGFR  PIK3CA   PIK3CB
# EGF-EGFR-PLCG-CAMK_signaling_pathway       EGF    EGFR   PLCG1    PLCG2
# EGF-EGFR-RAS-ERK_signaling_pathway         EGF    EGFR    GRB2     SOS1
# EGF-EGFR-RAS-RalGDS_signaling_pathway      EGF    EGFR    GRB2     SOS1
# EGF-EGFR-RAS-RASSF1_signaling_pathway      EGF    EGFR    GRB2     SOS1
# EGF-ERBB2-RAS-ERK_signaling_pathway        EGF   ERBB2    EGFR     GRB2
# EGF-Jak-STAT_signaling_pathway             EGF    EGFR    JAK1    STAT1
# FGF-FGFR-PI3K_signaling_pathway           FGF1    FGF2    FGF3     FGF4
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF1    FGF2    FGF3     FGF4
# FLT3LG-FLT3-RAS-ERK_signaling_pathway   FLT3LG    FLT3    GRB2     SOS1
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway  FLT3LG    FLT3    GRB2     SOS1
# FLT3LG-FLT3-STAT5_signaling_pathway     FLT3LG    FLT3  STAT5A   STAT5B
# Hedgehog_signaling_pathway                 SHH   PTCH1     SMO     SUFU
# HGF-MET-PI3K_signaling_pathway             HGF     MET    GAB1   PIK3CA
# HGF-MET-RAS-ERK_signaling_pathway          HGF     MET    GRB2     SOS1
# HIF-1_signaling_pathway                  HIF1A    ARNT  SLC2A1    VEGFA
# IGF2-IGF1R-PI3K_signaling_pathway         IGF1    IGF2   IGF1R     GRB2
# IGF-IGF1R-RAS-ERK_signaling_pathway       IGF2   IGF1R  PIK3CA   PIK3CB
# Intrinsic_apoptotic_pathway             PMAIP1    BBC3     BAD  BCL2L11
# KEAP1-NRF2_signaling_pathway             KEAP1  NFE2L2   HMOX1     NQO1
# KITLG-KIT-PI3K_signaling_pathway         KITLG     KIT  PIK3CA   PIK3CB
# KITLG-KIT-RAS-ERK_signaling_pathway      KITLG     KIT    GRB2     SOS1
# MDM2-p21-Cell_cycle_G1-S                CDKN2A    MDM2    TP53   CDKN1A
# NOTCH_signaling_pathway                   DLL1    DLL3    DLL4     JAG1
# p15-Cell_cycle_G1-S                        MYC     MAX  ZBTB17   CDKN2B
# p16-Cell_cycle_G1-S                     CDKN2A   CCND1   CCND2    CCND3
# p27-Cell_cycle_G1-S                       SKP1    CUL1    RBX1     SKP2
# PDGF-PDGFR-PI3K_signaling_pathway        PDGFA   PDGFB  PDGFRA   PDGFRB
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   PDGFA   PDGFB  PDGFRA   PDGFRB
# PDGF-PDGFR-RAS-ERK_signaling_pathway     PDGFA   PDGFB  PDGFRA   PDGFRB
# PTEN-PIP3-AKT_signaling_pathway           PTEN    AKT1    AKT2     AKT3
# Telomerase_activity                       TERC       0       0        0
# TGFA-EGFR-PI3K_signaling_pathway         TGFB1   TGFB2   TGFB3   TGFBR2
# TGFA-EGFR-PLCG-PKC_signaling_pathway      TGFA    EGFR  PIK3CA   PIK3CB
# TGFA-EGFR-RAS-ERK_signaling_pathway       TGFA    EGFR   PLCG1    PLCG2
# TGF-beta_signaling_pathway                TGFA    EGFR    GRB2     SOS1
# WNT_signaling_pathway                     WNT1    WNT2   WNT2B     WNT3
# NaN                                                 0       0        0
#
#                                             5       6       7       8   \
# 0
# Androgen_receptor_signaling_pathway          0       0       0       0
# Cytokine-Jak-STAT_signaling_pathway        IL6     IL7   IL12A   IL12B
# DCC-apoptotic_pathway                        0       0       0       0
# EGF-EGFR-PI3K_signaling_pathway         PIK3CD    AKT1    AKT2    AKT3
# EGF-EGFR-PLCG-CAMK_signaling_pathway     CALM1   CALM2   CALM3   CAMK1
# EGF-EGFR-RAS-ERK_signaling_pathway        SOS2    HRAS    KRAS    NRAS
# EGF-EGFR-RAS-RalGDS_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# EGF-EGFR-RAS-RASSF1_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# EGF-ERBB2-RAS-ERK_signaling_pathway       SOS1    SOS2    HRAS    KRAS
# EGF-Jak-STAT_signaling_pathway           STAT3  STAT5A  STAT5B       0
# FGF-FGFR-PI3K_signaling_pathway           FGF5    FGF6    FGF7    FGF8
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF5    FGF6    FGF7    FGF8
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway    SOS2    HRAS    KRAS    NRAS
# FLT3LG-FLT3-STAT5_signaling_pathway          0       0       0       0
# Hedgehog_signaling_pathway                GLI1    GLI2    GLI3    GLI1
# HGF-MET-PI3K_signaling_pathway          PIK3CB  PIK3CD    AKT1    AKT2
# HGF-MET-RAS-ERK_signaling_pathway         SOS2    HRAS    KRAS    NRAS
# HIF-1_signaling_pathway                  TGFB1   TGFB2   TGFB3   PDGFB
# IGF2-IGF1R-PI3K_signaling_pathway         SOS1    SOS2    HRAS    KRAS
# IGF-IGF1R-RAS-ERK_signaling_pathway     PIK3CD    AKT1    AKT2    AKT3
# Intrinsic_apoptotic_pathway               BCL2  BCL2L1     BAX    BAK1
# KEAP1-NRF2_signaling_pathway             GSTO2   GSTA5   GSTA1   GSTA2
# KITLG-KIT-PI3K_signaling_pathway        PIK3CD    AKT1    AKT2    AKT3
# KITLG-KIT-RAS-ERK_signaling_pathway       SOS2    HRAS    KRAS    NRAS
# MDM2-p21-Cell_cycle_G1-S                 CCND1   CCND2   CCND3    CDK4
# NOTCH_signaling_pathway                   JAG2  NOTCH1  NOTCH2  NOTCH3
# p15-Cell_cycle_G1-S                      CCND1   CCND2   CCND3    CDK4
# p16-Cell_cycle_G1-S                       CDK4    CDK6     RB1    E2F1
# p27-Cell_cycle_G1-S                     CDKN1B   CCNA2   CCNA1   CCNE1
# PDGF-PDGFR-PI3K_signaling_pathway       PIK3CA  PIK3CB  PIK3CD    AKT1
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   PLCG1   PLCG2   CALM1   CALM2
# PDGF-PDGFR-RAS-ERK_signaling_pathway      GRB2    SOS1    SOS2    HRAS
# PTEN-PIP3-AKT_signaling_pathway              0       0       0       0
# Telomerase_activity                          0       0       0       0
# TGFA-EGFR-PI3K_signaling_pathway        TGFBR1   SMAD2   SMAD3   SMAD4
# TGFA-EGFR-PLCG-PKC_signaling_pathway    PIK3CD    AKT1    AKT2    AKT3
# TGFA-EGFR-RAS-ERK_signaling_pathway      PRKCA   PRKCB   PRKCG    ELK1
# TGF-beta_signaling_pathway                SOS2    HRAS    KRAS    NRAS
# WNT_signaling_pathway                    WNT3A    WNT4   WNT5A   WNT5B
# NaN                                          0       0       0       0
#
#                                             9        10  ...     37     38  \
# 0                                                        ...
# Androgen_receptor_signaling_pathway          0        0  ...      0      0
# Cytokine-Jak-STAT_signaling_pathway       IL13     IL15  ...   JAK3  STAT1
# DCC-apoptotic_pathway                        0        0  ...      0      0
# EGF-EGFR-PI3K_signaling_pathway            BAD        0  ...      0      0
# EGF-EGFR-PLCG-CAMK_signaling_pathway    CAMK1D   CAMK1G  ...      0      0
# EGF-EGFR-RAS-ERK_signaling_pathway        ARAF     BRAF  ...      0      0
# EGF-EGFR-RAS-RalGDS_signaling_pathway   RALGDS     RALA  ...      0      0
# EGF-EGFR-RAS-RASSF1_signaling_pathway   RASSF1   RASSF5  ...      0      0
# EGF-ERBB2-RAS-ERK_signaling_pathway       NRAS     ARAF  ...      0      0
# EGF-Jak-STAT_signaling_pathway               0        0  ...      0      0
# FGF-FGFR-PI3K_signaling_pathway           FGF9    FGF10  ...      0      0
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF9    FGF10  ...      0      0
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     ARAF     BRAF  ...      0      0
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway  PIK3CA   PIK3CB  ...      0      0
# FLT3LG-FLT3-STAT5_signaling_pathway          0        0  ...      0      0
# Hedgehog_signaling_pathway               PTCH1    PTCH2  ...      0      0
# HGF-MET-PI3K_signaling_pathway            AKT3      BAD  ...      0      0
# HGF-MET-RAS-ERK_signaling_pathway         ARAF     BRAF  ...      0      0
# HIF-1_signaling_pathway                   TGFA        0  ...      0      0
# IGF2-IGF1R-PI3K_signaling_pathway         NRAS     ARAF  ...      0      0
# IGF-IGF1R-RAS-ERK_signaling_pathway       MTOR  RPS6KB1  ...      0      0
# Intrinsic_apoptotic_pathway               CYCS    APAF1  ...      0      0
# KEAP1-NRF2_signaling_pathway             GSTA3    GSTA4  ...      0      0
# KITLG-KIT-PI3K_signaling_pathway          MTOR  RPS6KB1  ...      0      0
# KITLG-KIT-RAS-ERK_signaling_pathway       ARAF     BRAF  ...      0      0
# MDM2-p21-Cell_cycle_G1-S                  CDK6      RB1  ...      0      0
# NOTCH_signaling_pathway                 NOTCH4     HES1  ...      0      0
# p15-Cell_cycle_G1-S                       CDK6      RB1  ...      0      0
# p16-Cell_cycle_G1-S                       E2F2     E2F3  ...      0      0
# p27-Cell_cycle_G1-S                      CCNE2     CDK2  ...      0      0
# PDGF-PDGFR-PI3K_signaling_pathway         AKT2     AKT3  ...      0      0
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   CALM3    CAMK1  ...      0      0
# PDGF-PDGFR-RAS-ERK_signaling_pathway      KRAS     NRAS  ...      0      0
# PTEN-PIP3-AKT_signaling_pathway              0        0  ...      0      0
# Telomerase_activity                          0        0  ...      0      0
# TGFA-EGFR-PI3K_signaling_pathway             0        0  ...      0      0
# TGFA-EGFR-PLCG-PKC_signaling_pathway      MTOR        0  ...      0      0
# TGFA-EGFR-RAS-ERK_signaling_pathway          0        0  ...      0      0
# TGF-beta_signaling_pathway                ARAF     BRAF  ...      0      0
# WNT_signaling_pathway                     WNT6    WNT7A  ...  AXIN1  AXIN2
# NaN                                          0        0  ...      0      0
#
#                                            39      40     41      42      43  \
# 0
# Androgen_receptor_signaling_pathway         0       0      0       0       0
# Cytokine-Jak-STAT_signaling_pathway     STAT2   STAT3  STAT4  STAT5A  STAT5B
# DCC-apoptotic_pathway                       0       0      0       0       0
# EGF-EGFR-PI3K_signaling_pathway             0       0      0       0       0
# EGF-EGFR-PLCG-CAMK_signaling_pathway        0       0      0       0       0
# EGF-EGFR-RAS-ERK_signaling_pathway          0       0      0       0       0
# EGF-EGFR-RAS-RalGDS_signaling_pathway       0       0      0       0       0
# EGF-EGFR-RAS-RASSF1_signaling_pathway       0       0      0       0       0
# EGF-ERBB2-RAS-ERK_signaling_pathway         0       0      0       0       0
# EGF-Jak-STAT_signaling_pathway              0       0      0       0       0
# FGF-FGFR-PI3K_signaling_pathway             0       0      0       0       0
# FGF-FGFR-RAS-ERK_signaling_pathway          0       0      0       0       0
# FLT3LG-FLT3-RAS-ERK_signaling_pathway       0       0      0       0       0
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway      0       0      0       0       0
# FLT3LG-FLT3-STAT5_signaling_pathway         0       0      0       0       0
# Hedgehog_signaling_pathway                  0       0      0       0       0
# HGF-MET-PI3K_signaling_pathway              0       0      0       0       0
# HGF-MET-RAS-ERK_signaling_pathway           0       0      0       0       0
# HIF-1_signaling_pathway                     0       0      0       0       0
# IGF2-IGF1R-PI3K_signaling_pathway           0       0      0       0       0
# IGF-IGF1R-RAS-ERK_signaling_pathway         0       0      0       0       0
# Intrinsic_apoptotic_pathway                 0       0      0       0       0
# KEAP1-NRF2_signaling_pathway                0       0      0       0       0
# KITLG-KIT-PI3K_signaling_pathway            0       0      0       0       0
# KITLG-KIT-RAS-ERK_signaling_pathway         0       0      0       0       0
# MDM2-p21-Cell_cycle_G1-S                    0       0      0       0       0
# NOTCH_signaling_pathway                     0       0      0       0       0
# p15-Cell_cycle_G1-S                         0       0      0       0       0
# p16-Cell_cycle_G1-S                         0       0      0       0       0
# p27-Cell_cycle_G1-S                         0       0      0       0       0
# PDGF-PDGFR-PI3K_signaling_pathway           0       0      0       0       0
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway      0       0      0       0       0
# PDGF-PDGFR-RAS-ERK_signaling_pathway        0       0      0       0       0
# PTEN-PIP3-AKT_signaling_pathway             0       0      0       0       0
# Telomerase_activity                         0       0      0       0       0
# TGFA-EGFR-PI3K_signaling_pathway            0       0      0       0       0
# TGFA-EGFR-PLCG-PKC_signaling_pathway        0       0      0       0       0
# TGFA-EGFR-RAS-ERK_signaling_pathway         0       0      0       0       0
# TGF-beta_signaling_pathway                  0       0      0       0       0
# WNT_signaling_pathway                     APC  CTNNB1   TCF7  TCF7L1  TCF7L2
# NaN                                         0       0      0       0       0
#
#                                            44    45     46
# 0
# Androgen_receptor_signaling_pathway         0     0      0
# Cytokine-Jak-STAT_signaling_pathway     STAT6  PIM1      0
# DCC-apoptotic_pathway                       0     0      0
# EGF-EGFR-PI3K_signaling_pathway             0     0      0
# EGF-EGFR-PLCG-CAMK_signaling_pathway        0     0      0
# EGF-EGFR-RAS-ERK_signaling_pathway          0     0      0
# EGF-EGFR-RAS-RalGDS_signaling_pathway       0     0      0
# EGF-EGFR-RAS-RASSF1_signaling_pathway       0     0      0
# EGF-ERBB2-RAS-ERK_signaling_pathway         0     0      0
# EGF-Jak-STAT_signaling_pathway              0     0      0
# FGF-FGFR-PI3K_signaling_pathway             0     0      0
# FGF-FGFR-RAS-ERK_signaling_pathway          0     0      0
# FLT3LG-FLT3-RAS-ERK_signaling_pathway       0     0      0
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway      0     0      0
# FLT3LG-FLT3-STAT5_signaling_pathway         0     0      0
# Hedgehog_signaling_pathway                  0     0      0
# HGF-MET-PI3K_signaling_pathway              0     0      0
# HGF-MET-RAS-ERK_signaling_pathway           0     0      0
# HIF-1_signaling_pathway                     0     0      0
# IGF2-IGF1R-PI3K_signaling_pathway           0     0      0
# IGF-IGF1R-RAS-ERK_signaling_pathway         0     0      0
# Intrinsic_apoptotic_pathway                 0     0      0
# KEAP1-NRF2_signaling_pathway                0     0      0
# KITLG-KIT-PI3K_signaling_pathway            0     0      0
# KITLG-KIT-RAS-ERK_signaling_pathway         0     0      0
# MDM2-p21-Cell_cycle_G1-S                    0     0      0
# NOTCH_signaling_pathway                     0     0      0
# p15-Cell_cycle_G1-S                         0     0      0
# p16-Cell_cycle_G1-S                         0     0      0
# p27-Cell_cycle_G1-S                         0     0      0
# PDGF-PDGFR-PI3K_signaling_pathway           0     0      0
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway      0     0      0
# PDGF-PDGFR-RAS-ERK_signaling_pathway        0     0      0
# PTEN-PIP3-AKT_signaling_pathway             0     0      0
# Telomerase_activity                         0     0      0
# TGFA-EGFR-PI3K_signaling_pathway            0     0      0
# TGFA-EGFR-PLCG-PKC_signaling_pathway        0     0      0
# TGFA-EGFR-RAS-ERK_signaling_pathway         0     0      0
# TGF-beta_signaling_pathway                  0     0      0
# WNT_signaling_pathway                    LEF1   MYC  CCND1
# NaN                                         0     0      0
#
# [41 rows x 46 columns]

# %%
pathways=pathways.drop(pathways.index[40])
pathways
# Out:
#                                             1       2       3        4   \
# 0
# Androgen_receptor_signaling_pathway         AR    KLK3       0        0
# Cytokine-Jak-STAT_signaling_pathway        IL2     IL3     IL4      IL5
# DCC-apoptotic_pathway                    CASP3     DCC   CASP9    APPL1
# EGF-EGFR-PI3K_signaling_pathway            EGF    EGFR  PIK3CA   PIK3CB
# EGF-EGFR-PLCG-CAMK_signaling_pathway       EGF    EGFR   PLCG1    PLCG2
# EGF-EGFR-RAS-ERK_signaling_pathway         EGF    EGFR    GRB2     SOS1
# EGF-EGFR-RAS-RalGDS_signaling_pathway      EGF    EGFR    GRB2     SOS1
# EGF-EGFR-RAS-RASSF1_signaling_pathway      EGF    EGFR    GRB2     SOS1
# EGF-ERBB2-RAS-ERK_signaling_pathway        EGF   ERBB2    EGFR     GRB2
# EGF-Jak-STAT_signaling_pathway             EGF    EGFR    JAK1    STAT1
# FGF-FGFR-PI3K_signaling_pathway           FGF1    FGF2    FGF3     FGF4
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF1    FGF2    FGF3     FGF4
# FLT3LG-FLT3-RAS-ERK_signaling_pathway   FLT3LG    FLT3    GRB2     SOS1
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway  FLT3LG    FLT3    GRB2     SOS1
# FLT3LG-FLT3-STAT5_signaling_pathway     FLT3LG    FLT3  STAT5A   STAT5B
# Hedgehog_signaling_pathway                 SHH   PTCH1     SMO     SUFU
# HGF-MET-PI3K_signaling_pathway             HGF     MET    GAB1   PIK3CA
# HGF-MET-RAS-ERK_signaling_pathway          HGF     MET    GRB2     SOS1
# HIF-1_signaling_pathway                  HIF1A    ARNT  SLC2A1    VEGFA
# IGF2-IGF1R-PI3K_signaling_pathway         IGF1    IGF2   IGF1R     GRB2
# IGF-IGF1R-RAS-ERK_signaling_pathway       IGF2   IGF1R  PIK3CA   PIK3CB
# Intrinsic_apoptotic_pathway             PMAIP1    BBC3     BAD  BCL2L11
# KEAP1-NRF2_signaling_pathway             KEAP1  NFE2L2   HMOX1     NQO1
# KITLG-KIT-PI3K_signaling_pathway         KITLG     KIT  PIK3CA   PIK3CB
# KITLG-KIT-RAS-ERK_signaling_pathway      KITLG     KIT    GRB2     SOS1
# MDM2-p21-Cell_cycle_G1-S                CDKN2A    MDM2    TP53   CDKN1A
# NOTCH_signaling_pathway                   DLL1    DLL3    DLL4     JAG1
# p15-Cell_cycle_G1-S                        MYC     MAX  ZBTB17   CDKN2B
# p16-Cell_cycle_G1-S                     CDKN2A   CCND1   CCND2    CCND3
# p27-Cell_cycle_G1-S                       SKP1    CUL1    RBX1     SKP2
# PDGF-PDGFR-PI3K_signaling_pathway        PDGFA   PDGFB  PDGFRA   PDGFRB
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   PDGFA   PDGFB  PDGFRA   PDGFRB
# PDGF-PDGFR-RAS-ERK_signaling_pathway     PDGFA   PDGFB  PDGFRA   PDGFRB
# PTEN-PIP3-AKT_signaling_pathway           PTEN    AKT1    AKT2     AKT3
# Telomerase_activity                       TERC       0       0        0
# TGFA-EGFR-PI3K_signaling_pathway         TGFB1   TGFB2   TGFB3   TGFBR2
# TGFA-EGFR-PLCG-PKC_signaling_pathway      TGFA    EGFR  PIK3CA   PIK3CB
# TGFA-EGFR-RAS-ERK_signaling_pathway       TGFA    EGFR   PLCG1    PLCG2
# TGF-beta_signaling_pathway                TGFA    EGFR    GRB2     SOS1
# WNT_signaling_pathway                     WNT1    WNT2   WNT2B     WNT3
#
#                                             5       6       7       8   \
# 0
# Androgen_receptor_signaling_pathway          0       0       0       0
# Cytokine-Jak-STAT_signaling_pathway        IL6     IL7   IL12A   IL12B
# DCC-apoptotic_pathway                        0       0       0       0
# EGF-EGFR-PI3K_signaling_pathway         PIK3CD    AKT1    AKT2    AKT3
# EGF-EGFR-PLCG-CAMK_signaling_pathway     CALM1   CALM2   CALM3   CAMK1
# EGF-EGFR-RAS-ERK_signaling_pathway        SOS2    HRAS    KRAS    NRAS
# EGF-EGFR-RAS-RalGDS_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# EGF-EGFR-RAS-RASSF1_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# EGF-ERBB2-RAS-ERK_signaling_pathway       SOS1    SOS2    HRAS    KRAS
# EGF-Jak-STAT_signaling_pathway           STAT3  STAT5A  STAT5B       0
# FGF-FGFR-PI3K_signaling_pathway           FGF5    FGF6    FGF7    FGF8
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF5    FGF6    FGF7    FGF8
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     SOS2    HRAS    KRAS    NRAS
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway    SOS2    HRAS    KRAS    NRAS
# FLT3LG-FLT3-STAT5_signaling_pathway          0       0       0       0
# Hedgehog_signaling_pathway                GLI1    GLI2    GLI3    GLI1
# HGF-MET-PI3K_signaling_pathway          PIK3CB  PIK3CD    AKT1    AKT2
# HGF-MET-RAS-ERK_signaling_pathway         SOS2    HRAS    KRAS    NRAS
# HIF-1_signaling_pathway                  TGFB1   TGFB2   TGFB3   PDGFB
# IGF2-IGF1R-PI3K_signaling_pathway         SOS1    SOS2    HRAS    KRAS
# IGF-IGF1R-RAS-ERK_signaling_pathway     PIK3CD    AKT1    AKT2    AKT3
# Intrinsic_apoptotic_pathway               BCL2  BCL2L1     BAX    BAK1
# KEAP1-NRF2_signaling_pathway             GSTO2   GSTA5   GSTA1   GSTA2
# KITLG-KIT-PI3K_signaling_pathway        PIK3CD    AKT1    AKT2    AKT3
# KITLG-KIT-RAS-ERK_signaling_pathway       SOS2    HRAS    KRAS    NRAS
# MDM2-p21-Cell_cycle_G1-S                 CCND1   CCND2   CCND3    CDK4
# NOTCH_signaling_pathway                   JAG2  NOTCH1  NOTCH2  NOTCH3
# p15-Cell_cycle_G1-S                      CCND1   CCND2   CCND3    CDK4
# p16-Cell_cycle_G1-S                       CDK4    CDK6     RB1    E2F1
# p27-Cell_cycle_G1-S                     CDKN1B   CCNA2   CCNA1   CCNE1
# PDGF-PDGFR-PI3K_signaling_pathway       PIK3CA  PIK3CB  PIK3CD    AKT1
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   PLCG1   PLCG2   CALM1   CALM2
# PDGF-PDGFR-RAS-ERK_signaling_pathway      GRB2    SOS1    SOS2    HRAS
# PTEN-PIP3-AKT_signaling_pathway              0       0       0       0
# Telomerase_activity                          0       0       0       0
# TGFA-EGFR-PI3K_signaling_pathway        TGFBR1   SMAD2   SMAD3   SMAD4
# TGFA-EGFR-PLCG-PKC_signaling_pathway    PIK3CD    AKT1    AKT2    AKT3
# TGFA-EGFR-RAS-ERK_signaling_pathway      PRKCA   PRKCB   PRKCG    ELK1
# TGF-beta_signaling_pathway                SOS2    HRAS    KRAS    NRAS
# WNT_signaling_pathway                    WNT3A    WNT4   WNT5A   WNT5B
#
#                                             9        10  ...     37     38  \
# 0                                                        ...
# Androgen_receptor_signaling_pathway          0        0  ...      0      0
# Cytokine-Jak-STAT_signaling_pathway       IL13     IL15  ...   JAK3  STAT1
# DCC-apoptotic_pathway                        0        0  ...      0      0
# EGF-EGFR-PI3K_signaling_pathway            BAD        0  ...      0      0
# EGF-EGFR-PLCG-CAMK_signaling_pathway    CAMK1D   CAMK1G  ...      0      0
# EGF-EGFR-RAS-ERK_signaling_pathway        ARAF     BRAF  ...      0      0
# EGF-EGFR-RAS-RalGDS_signaling_pathway   RALGDS     RALA  ...      0      0
# EGF-EGFR-RAS-RASSF1_signaling_pathway   RASSF1   RASSF5  ...      0      0
# EGF-ERBB2-RAS-ERK_signaling_pathway       NRAS     ARAF  ...      0      0
# EGF-Jak-STAT_signaling_pathway               0        0  ...      0      0
# FGF-FGFR-PI3K_signaling_pathway           FGF9    FGF10  ...      0      0
# FGF-FGFR-RAS-ERK_signaling_pathway        FGF9    FGF10  ...      0      0
# FLT3LG-FLT3-RAS-ERK_signaling_pathway     ARAF     BRAF  ...      0      0
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway  PIK3CA   PIK3CB  ...      0      0
# FLT3LG-FLT3-STAT5_signaling_pathway          0        0  ...      0      0
# Hedgehog_signaling_pathway               PTCH1    PTCH2  ...      0      0
# HGF-MET-PI3K_signaling_pathway            AKT3      BAD  ...      0      0
# HGF-MET-RAS-ERK_signaling_pathway         ARAF     BRAF  ...      0      0
# HIF-1_signaling_pathway                   TGFA        0  ...      0      0
# IGF2-IGF1R-PI3K_signaling_pathway         NRAS     ARAF  ...      0      0
# IGF-IGF1R-RAS-ERK_signaling_pathway       MTOR  RPS6KB1  ...      0      0
# Intrinsic_apoptotic_pathway               CYCS    APAF1  ...      0      0
# KEAP1-NRF2_signaling_pathway             GSTA3    GSTA4  ...      0      0
# KITLG-KIT-PI3K_signaling_pathway          MTOR  RPS6KB1  ...      0      0
# KITLG-KIT-RAS-ERK_signaling_pathway       ARAF     BRAF  ...      0      0
# MDM2-p21-Cell_cycle_G1-S                  CDK6      RB1  ...      0      0
# NOTCH_signaling_pathway                 NOTCH4     HES1  ...      0      0
# p15-Cell_cycle_G1-S                       CDK6      RB1  ...      0      0
# p16-Cell_cycle_G1-S                       E2F2     E2F3  ...      0      0
# p27-Cell_cycle_G1-S                      CCNE2     CDK2  ...      0      0
# PDGF-PDGFR-PI3K_signaling_pathway         AKT2     AKT3  ...      0      0
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway   CALM3    CAMK1  ...      0      0
# PDGF-PDGFR-RAS-ERK_signaling_pathway      KRAS     NRAS  ...      0      0
# PTEN-PIP3-AKT_signaling_pathway              0        0  ...      0      0
# Telomerase_activity                          0        0  ...      0      0
# TGFA-EGFR-PI3K_signaling_pathway             0        0  ...      0      0
# TGFA-EGFR-PLCG-PKC_signaling_pathway      MTOR        0  ...      0      0
# TGFA-EGFR-RAS-ERK_signaling_pathway          0        0  ...      0      0
# TGF-beta_signaling_pathway                ARAF     BRAF  ...      0      0
# WNT_signaling_pathway                     WNT6    WNT7A  ...  AXIN1  AXIN2
#
#                                            39      40     41      42      43  \
# 0
# Androgen_receptor_signaling_pathway         0       0      0       0       0
# Cytokine-Jak-STAT_signaling_pathway     STAT2   STAT3  STAT4  STAT5A  STAT5B
# DCC-apoptotic_pathway                       0       0      0       0       0
# EGF-EGFR-PI3K_signaling_pathway             0       0      0       0       0
# EGF-EGFR-PLCG-CAMK_signaling_pathway        0       0      0       0       0
# EGF-EGFR-RAS-ERK_signaling_pathway          0       0      0       0       0
# EGF-EGFR-RAS-RalGDS_signaling_pathway       0       0      0       0       0
# EGF-EGFR-RAS-RASSF1_signaling_pathway       0       0      0       0       0
# EGF-ERBB2-RAS-ERK_signaling_pathway         0       0      0       0       0
# EGF-Jak-STAT_signaling_pathway              0       0      0       0       0
# FGF-FGFR-PI3K_signaling_pathway             0       0      0       0       0
# FGF-FGFR-RAS-ERK_signaling_pathway          0       0      0       0       0
# FLT3LG-FLT3-RAS-ERK_signaling_pathway       0       0      0       0       0
# FLT3LG-FLT3-RAS-PI3K_signaling_pathway      0       0      0       0       0
# FLT3LG-FLT3-STAT5_signaling_pathway         0       0      0       0       0
# Hedgehog_signaling_pathway                  0       0      0       0       0
# HGF-MET-PI3K_signaling_pathway              0       0      0       0       0
# HGF-MET-RAS-ERK_signaling_pathway           0       0      0       0       0
# HIF-1_signaling_pathway                     0       0      0       0       0
# IGF2-IGF1R-PI3K_signaling_pathway           0       0      0       0       0
# IGF-IGF1R-RAS-ERK_signaling_pathway         0       0      0       0       0
# Intrinsic_apoptotic_pathway                 0       0      0       0       0
# KEAP1-NRF2_signaling_pathway                0       0      0       0       0
# KITLG-KIT-PI3K_signaling_pathway            0       0      0       0       0
# KITLG-KIT-RAS-ERK_signaling_pathway         0       0      0       0       0
# MDM2-p21-Cell_cycle_G1-S                    0       0      0       0       0
# NOTCH_signaling_pathway                     0       0      0       0       0
# p15-Cell_cycle_G1-S                         0       0      0       0       0
# p16-Cell_cycle_G1-S                         0       0      0       0       0
# p27-Cell_cycle_G1-S                         0       0      0       0       0
# PDGF-PDGFR-PI3K_signaling_pathway           0       0      0       0       0
# PDGF-PDGFR-PLCG-CAMK_signaling_pathway      0       0      0       0       0
# PDGF-PDGFR-RAS-ERK_signaling_pathway        0       0      0       0       0
# PTEN-PIP3-AKT_signaling_pathway             0       0      0       0       0
# Telomerase_activity                         0       0      0       0       0
# TGFA-EGFR-PI3K_signaling_pathway            0       0      0       0       0
# TGFA-EGFR-PLCG-PKC_signaling_pathway        0       0      0       0       0
# TGFA-EGFR-RAS-ERK_signaling_pathway         0       0      0       0       0
# TGF-beta_signaling_pathway                  0       0      0       0       0
# WNT_signaling_pathway                     APC  CTNNB1   TCF7  TCF7L1  TCF7L2
#
#                                            44    45     46
# 0
# Androgen_receptor_signaling_pathway         0     0      0
# Cytokine-Jak-STAT_signaling_pathway     STAT6  PIM1      0
# DCC-apoptotic_pathway                       0     0      0
# EGF-EGFR-PI3K_signaling_pathway             0     0      0
# EGF-EGFR-PLCG-CAMK_signaling_pathway        0     0      0
# EGF-EGFR-RAS-ERK_signaling_pathway          0     0      0
# EGF-EGFR-RAS-RalGDS_signaling_pathway       0     0      0
# CDK2        0.578289    0.341637    0.387449    0.512483    0.380629  ...
# CDK4        0.385666    0.275441    0.271883    0.417030    0.280183  ...
# ...              ...         ...         ...         ...         ...  ...
# CCNE2       0.592050    0.323691    0.265539    0.389999    0.000000  ...
# GSTO1       0.517040    0.998278    0.820274    0.593057    0.290432  ...
# KEAP1       0.740486    0.813999    0.771060    0.780026    0.663367  ...
# FGF19       0.102683    0.095321    0.149639    0.123341    0.147740  ...
# RBX1        0.574375    0.573328    0.465751    0.197338    0.117679  ...
#
#           GSM1855230  GSM1855231  GSM1855232  GSM1855233  GSM1855234  \
# geneName
# AKT3        0.188648    0.479748    0.525943    0.545923    0.430042
# BCL2L11     0.372622    0.430423    0.491508    0.534332    0.468523
# FRAT1       0.404515    0.622529    0.420353    0.407280    0.195559
# CDK2        0.533463    0.546288    0.764869    0.685792    0.449021
# CDK4        0.530565    0.416870    0.482185    0.519606    0.436227
# ...              ...         ...         ...         ...         ...
# CCNE2       0.507930    0.485317    0.449540    0.455459    0.372189
# GSTO1       0.628263    0.666089    0.905016    0.663222    0.586077
# KEAP1       0.750321    0.617769    0.545393    0.723468    0.747913
# FGF19       0.099747    0.047404    0.258835    0.159050    0.216512
# RBX1        0.096119    0.311267    0.127701    0.480255    0.157973
#
#           GSM1855235  GSM1855236  GSM1855237  GSM1855238  geneName
# geneName
# AKT3        0.236169    0.366298    0.347796    0.651945      AKT3
# BCL2L11     0.439226    0.528650    0.639826    0.450066   BCL2L11
# FRAT1       0.482192    0.810118    0.540869    0.536168     FRAT1
# CDK2        0.301685    0.445637    0.656822    0.502931      CDK2
# CDK4        0.220103    0.473477    0.305762    0.484318      CDK4
# ...              ...         ...         ...         ...       ...
# CCNE2       0.235105    0.427181    0.418995    0.557354     CCNE2
# GSTO1       0.428510    0.445268    0.941123    0.569243     GSTO1
# KEAP1       0.680744    0.732421    0.809131    0.675140     KEAP1
# FGF19       0.092970    0.134765    0.067895    0.104985     FGF19
# RBX1        0.131389    0.286034    0.481712    0.324958      RBX1
#
# [274 rows x 443 columns]

# %%
col_72904=gse72904_exp.columns.tolist()
col_72904.remove('geneName')
col_72904
# Out:
# ['GSM1854797',
#  'GSM1854798',
#  'GSM1854799',
#  'GSM1854800',
#  'GSM1854801',
#  'GSM1854802',
#  'GSM1854803',
#  'GSM1854804',
#  'GSM1854805',
#  'GSM1854806',
#  'GSM1854807',
#  'GSM1854808',
#  'GSM1854809',
#  'GSM1854810',
#  'GSM1854811',
#  'GSM1854812',
#  'GSM1854813',
#  'GSM1854814',
#  'GSM1854815',
#  'GSM1854816',
#  'GSM1854817',
#  'GSM1854818',
#  'GSM1854819',
#  'GSM1854820',
#  'GSM1854821',
#  'GSM1854822',
#  'GSM1854823',
#  'GSM1854824',
#  'GSM1854825',
#  'GSM1854826',
#  'GSM1854827',
#  'GSM1854828',
#  'GSM1854829',
#  'GSM1854830',
#  'GSM1854831',
#  'GSM1854832',
#  'GSM1854833',
#  'GSM1854834',
#  'GSM1854835',
#  'GSM1854836',
#  'GSM1854837',
#  'GSM1854838',
#  'GSM1854839',
#  'GSM1854840',
#  'GSM1854841',
#  'GSM1854842',
#  'GSM1854843',
#  'GSM1854844',
#  'GSM1854845',
#  'GSM1854846',
#  'GSM1854847',
#  'GSM1854848',
#  'GSM1854849',
#  'GSM1854850',
#  'GSM1854851',
#  'GSM1854852',
#  'GSM1854853',
#  'GSM1854854',
#  'GSM1854855',
#  'GSM1854856',
#  'GSM1854857',
#  'GSM1854858',
#  'GSM1854859',
#  'GSM1854860',
#  'GSM1854861',
#  'GSM1854862',
#  'GSM1854863',
#  'GSM1854864',
#  'GSM1854865',
#  'GSM1854866',
#  'GSM1854867',
#  'GSM1854868',
#  'GSM1854869',
#  'GSM1854870',
#  'GSM1854871',
#  'GSM1854872',
#  'GSM1854873',
#  'GSM1854874',
#  'GSM1854875',
#  'GSM1854876',
#  'GSM1854877',
#  'GSM1854878',
#  'GSM1854879',
#  'GSM1854880',
#  'GSM1854881',
#  'GSM1854882',
#  'GSM1854883',
#  'GSM1854884',
#  'GSM1854885',
#  'GSM1854886',
#  'GSM1854887',
#  'GSM1854888',
#  'GSM1854889',
#  'GSM1854890',
#  'GSM1854891',
#  'GSM1854892',
#  'GSM1854893',
#  'GSM1854894',
#  'GSM1854895',
#  'GSM1854896',
#  'GSM1854897',
#  'GSM1854898',
#  'GSM1854899',
#  'GSM1854900',
#  'GSM1854901',
#  'GSM1854902',
#  'GSM1854903',
#  'GSM1854904',
#  'GSM1854905',
#  'GSM1854906',
#  'GSM1854907',
#  'GSM1854908',
#  'GSM1854909',
#  'GSM1854910',
#  'GSM1854911',
#  'GSM1854912',
#  'GSM1854913',
#  'GSM1854914',
#  'GSM1854915',
#  'GSM1854916',
#  'GSM1854917',
#  'GSM1854918',
#  'GSM1854919',
#  'GSM1854920',
#  'GSM1854921',
#  'GSM1854922',
#  'GSM1854923',
#  'GSM1854924',
#  'GSM1854925',
#  'GSM1854926',
#  'GSM1854927',
#  'GSM1854928',
#  'GSM1854929',
#  'GSM1854930',
#  'GSM1854931',
#  'GSM1854932',
#  'GSM1854933',
#  'GSM1854934',
#  'GSM1854935',
#  'GSM1854936',
#  'GSM1854937',
#  'GSM1854938',
#  'GSM1854939',
#  'GSM1854940',
#  'GSM1854941',
#  'GSM1854942',
#  'GSM1854943',
#  'GSM1854944',
#  'GSM1854945',
#  'GSM1854946',
#  'GSM1854947',
#  'GSM1854948',
#  'GSM1854949',
#  'GSM1854950',
#  'GSM1854951',
#  'GSM1854952',
#  'GSM1854953',
#  'GSM1854954',
#  'GSM1854955',
#  'GSM1854956',
#  'GSM1854957',
#  'GSM1854958',
#  'GSM1854959',
#  'GSM1854960',
#  'GSM1854961',
#  'GSM1854962',
#  'GSM1854963',
#  'GSM1854964',
#  'GSM1854965',
#  'GSM1854966',
#  'GSM1854967',
#  'GSM1854968',
#  'GSM1854969',
#  'GSM1854970',
#  'GSM1854971',
#  'GSM1854972',
#  'GSM1854973',
#  'GSM1854974',
#  'GSM1854975',
#  'GSM1854976',
#  'GSM1854977',
#  'GSM1854978',
#  'GSM1854979',
#  'GSM1854980',
#  'GSM1854981',
#  'GSM1854982',
#  'GSM1854983',
#  'GSM1854984',
#  'GSM1854985',
#  'GSM1854986',
#  'GSM1854987',
#  'GSM1854988',
#  'GSM1854989',
#  'GSM1854990',
#  'GSM1854991',
#  'GSM1854992',
#  'GSM1854993',
#  'GSM1854994',
#  'GSM1854995',
#  'GSM1854996',
#  'GSM1854997',
#  'GSM1854998',
#  'GSM1854999',
#  'GSM1855000',
#  'GSM1855001',
#  'GSM1855002',
#  'GSM1855003',
#  'GSM1855004',
#  'GSM1855005',
#  'GSM1855006',
#  'GSM1855007',
#  'GSM1855008',
#  'GSM1855009',
#  'GSM1855010',
#  'GSM1855011',
#  'GSM1855012',
#  'GSM1855013',
#  'GSM1855014',
#  'GSM1855015',
#  'GSM1855016',
#  'GSM1855017',
#  'GSM1855018',
#  'GSM1855019',
#  'GSM1855020',
#  'GSM1855021',
#  'GSM1855022',
#  'GSM1855023',
#  'GSM1855024',
#  'GSM1855025',
#  'GSM1855026',
#  'GSM1855027',
#  'GSM1855028',
#  'GSM1855029',
#  'GSM1855030',
#  'GSM1855031',
#  'GSM1855032',
#  'GSM1855033',
#  'GSM1855034',
#  'GSM1855035',
#  'GSM1855036',
#  'GSM1855037',
#  'GSM1855038',
#  'GSM1855039',
#  'GSM1855040',
#  'GSM1855041',
#  'GSM1855042',
#  'GSM1855043',
#  'GSM1855044',
#  'GSM1855045',
#  'GSM1855046',
#  'GSM1855047',
#  'GSM1855048',
#  'GSM1855049',
#  'GSM1855050',
#  'GSM1855051',
#  'GSM1855052',
#  'GSM1855053',
#  'GSM1855054',
#  'GSM1855055',
#  'GSM1855056',
#  'GSM1855057',
#  'GSM1855058',
#  'GSM1855059',
#  'GSM1855060',
#  'GSM1855061',
#  'GSM1855062',
#  'GSM1855063',
#  'GSM1855064',
#  'GSM1855065',
#  'GSM1855066',
#  'GSM1855067',
#  'GSM1855068',
#  'GSM1855069',
#  'GSM1855070',
#  'GSM1855071',
#  'GSM1855072',
#  'GSM1855073',
#  'GSM1855074',
#  'GSM1855075',
#  'GSM1855076',
#  'GSM1855077',
#  'GSM1855078',
#  'GSM1855079',
#  'GSM1855080',
#  'GSM1855081',
#  'GSM1855082',
#  'GSM1855083',
#  'GSM1855084',
#  'GSM1855085',
#  'GSM1855086',
#  'GSM1855087',
#  'GSM1855088',
#  'GSM1855089',
#  'GSM1855090',
#  'GSM1855091',
#  'GSM1855092',
#  'GSM1855093',
#  'GSM1855094',
#  'GSM1855095',
#  'GSM1855096',
#  'GSM1855097',
#  'GSM1855098',
#  'GSM1855099',
#  'GSM1855100',
#  'GSM1855101',
#  'GSM1855102',
#  'GSM1855103',
#  'GSM1855104',
#  'GSM1855105',
#  'GSM1855106',
#  'GSM1855107',
#  'GSM1855108',
#  'GSM1855109',
#  'GSM1855110',
#  'GSM1855111',
#  'GSM1855112',
#  'GSM1855113',
#  'GSM1855114',
#  'GSM1855115',
#  'GSM1855116',
#  'GSM1855117',
#  'GSM1855118',
#  'GSM1855119',
#  'GSM1855120',
#  'GSM1855121',
#  'GSM1855122',
#  'GSM1855123',
#  'GSM1855124',
#  'GSM1855125',
#  'GSM1855126',
#  'GSM1855127',
#  'GSM1855128',
#  'GSM1855129',
#  'GSM1855130',
#  'GSM1855131',
#  'GSM1855132',
#  'GSM1855133',
#  'GSM1855134',
#  'GSM1855135',
#  'GSM1855136',
#  'GSM1855137',
#  'GSM1855138',
#  'GSM1855139',
#  'GSM1855140',
#  'GSM1855141',
#  'GSM1855142',
#  'GSM1855143',
#  'GSM1855144',
#  'GSM1855145',
#  'GSM1855146',
#  'GSM1855147',
#  'GSM1855148',
#  'GSM1855149',
#  'GSM1855150',
#  'GSM1855151',
#  'GSM1855152',
#  'GSM1855153',
#  'GSM1855154',
#  'GSM1855155',
#  'GSM1855156',
#  'GSM1855157',
#  'GSM1855158',
#  'GSM1855159',
#  'GSM1855160',
#  'GSM1855161',
#  'GSM1855162',
#  'GSM1855163',
#  'GSM1855164',
#  'GSM1855165',
#  'GSM1855166',
#  'GSM1855167',
#  'GSM1855168',
#  'GSM1855169',
#  'GSM1855170',
#  'GSM1855171',
#  'GSM1855172',
#  'GSM1855173',
#  'GSM1855174',
#  'GSM1855175',
#  'GSM1855176',
#  'GSM1855177',
#  'GSM1855178',
#  'GSM1855179',
#  'GSM1855180',
#  'GSM1855181',
#  'GSM1855182',
#  'GSM1855183',
#  'GSM1855184',
#  'GSM1855185',
#  'GSM1855186',
#  'GSM1855187',
#  'GSM1855188',
#  'GSM1855189',
#  'GSM1855190',
#  'GSM1855191',
#  'GSM1855192',
#  'GSM1855193',
#  'GSM1855194',
#  'GSM1855195',
#  'GSM1855196',
#  'GSM1855197',
#  'GSM1855198',
#  'GSM1855199',
#  'GSM1855200',
#  'GSM1855201',
#  'GSM1855202',
#  'GSM1855203',
#  'GSM1855204',
#  'GSM1855205',
#  'GSM1855206',
#  'GSM1855207',
#  'GSM1855208',
#  'GSM1855209',
#  'GSM1855210',
#  'GSM1855211',
#  'GSM1855212',
#  'GSM1855213',
#  'GSM1855214',
#  'GSM1855215',
#  'GSM1855216',
#  'GSM1855217',
#  'GSM1855218',
#  'GSM1855219',
#  'GSM1855220',
#  'GSM1855221',
#  'GSM1855222',
#  'GSM1855223',
#  'GSM1855224',
#  'GSM1855225',
#  'GSM1855226',
#  'GSM1855227',
#  'GSM1855228',
#  'GSM1855229',
#  'GSM1855230',
#  'GSM1855231',
#  'GSM1855232',
#  'GSM1855233',
#  'GSM1855234',
#  'GSM1855235',
#  'GSM1855236',
#  'GSM1855237',
#  'GSM1855238']

# %%
len(pathways)
# Out:
# 40

# %%
sample='GSM1854797'
expre_mat=np.empty((40,46))
for i in range(len(pathways)):
    pathway=np.array(pathways.iloc[i]).tolist()
    path_expre=[0 for r in range(46)]
    for j in range(len(pathway)):
        #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
        if pathway[j] in set(gse72904_exp['geneName']):
            path_expre[j]=gse72904_exp[gse72904_exp['geneName']==pathway[j]][sample].values
        else:
            path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
    expre_mat[i]=path_expre
list49=[0 for m in range(49)]
list46=[0 for n in range(46)]
for p in range(9):
    expre_mat=np.row_stack((expre_mat,list46))
for q in range(3):
    expre_mat=np.column_stack((expre_mat,list49))
expre_df=pd.DataFrame(expre_mat).T
chunk1=expre_df.iloc[:,0].values.reshape(7,7)
chunk2=expre_df.iloc[:,7].values.reshape(7,7)
chunk3=expre_df.iloc[:,14].values.reshape(7,7)
chunk4=expre_df.iloc[:,21].values.reshape(7,7)
chunk5=expre_df.iloc[:,28].values.reshape(7,7)
chunk6=expre_df.iloc[:,35].values.reshape(7,7)
chunk7=expre_df.iloc[:,42].values.reshape(7,7)
for c in range(1,7):
    block=expre_df.iloc[:,c].values.reshape(7,7)
    chunk1=np.concatenate([chunk1,block],axis=1)
for c in range(8,14):
    block=expre_df.iloc[:,c].values.reshape(7,7)
    chunk2=np.concatenate([chunk2,block],axis=1)
for c in range(15,21):
    block=expre_df.iloc[:,c].values.reshape(7,7)
    chunk3=np.concatenate([chunk3,block],axis=1)
for c in range(22,28):
    block=expre_df.iloc[:,c].values.reshape(7,7)
    chunk4=np.concatenate([chunk4,block],axis=1)
for c in range(29,35):
    block=expre_df.iloc[:,c].values.reshape(7,7)
    chunk5=np.concatenate([chunk5,block],axis=1)
for c in range(36,42):
    block=expre_df.iloc[:,c].values.reshape(7,7)
    chunk6=np.concatenate([chunk6,block],axis=1)
for c in range(43,49):
    block=expre_df.iloc[:,c].values.reshape(7,7)
    chunk7=np.concatenate([chunk7,block],axis=1)
pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
# Out:
# C:\Users\23247\AppData\Local\Temp\ipykernel_14744\1071409035.py:15: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   expre_mat[i]=path_expre

# %%
import matplotlib.pyplot as plt # plt Used to display images
import matplotlib.image as mpimg # mpimg Used to load images
import matplotlib.cm as c

plt.imshow(pathway_blocks,c.hot) # display

# %% [markdown]
# ## LUAD Formation

# %%
# %%time
from tqdm import tqdm
import time
for sample in tqdm(col_72904):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse72904_exp['geneName']):
                path_expre[j]=gse72904_exp[gse72904_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/442 [00:00<?, ?it/s]<timed exec>:18: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 442/442 [01:05<00:00,  6.74it/s]
# CPU times: total: 1min 5s
# Wall time: 1min 5s

# %%
# %%time
col_consort=consortium_exp.columns.tolist()
col_consort.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_consort):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(consortium_exp['geneName']):
                path_expre[j]=consortium_exp[consortium_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/442 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 442/442 [01:00<00:00,  7.31it/s]
# CPU times: total: 1min
# Wall time: 1min

# %%
# %%time
col_41271=gse41271_exp.columns.tolist()
col_41271.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_41271):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse41271_exp['geneName']):
                path_expre[j]=gse41271_exp[gse41271_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/275 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 275/275 [00:40<00:00,  6.86it/s]
# CPU times: total: 40 s
# Wall time: 40.1 s

# %%
# %%time
col_31210=gse31210_exp.columns.tolist()
col_31210.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_31210):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse31210_exp['geneName']):
                path_expre[j]=gse31210_exp[gse31210_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/224 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 224/224 [00:32<00:00,  6.95it/s]
# CPU times: total: 32.2 s
# Wall time: 32.3 s

# %%
# %%time
col_pnas=pnas_exp.columns.tolist()
col_pnas.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_pnas):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(pnas_exp['geneName']):
                path_expre[j]=pnas_exp[pnas_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/203 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 203/203 [00:25<00:00,  7.82it/s]
# CPU times: total: 26 s
# Wall time: 26 s

# %%
# %%time
col_11969=gse11969_exp.columns.tolist()
col_11969.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_11969):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse11969_exp['geneName']):
                path_expre[j]=gse11969_exp[gse11969_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/163 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 163/163 [00:23<00:00,  7.01it/s]
# CPU times: total: 23.3 s
# Wall time: 23.3 s

# %%
# %%time
col_20853=gse20853_exp.columns.tolist()
col_20853.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_20853):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse20853_exp['geneName']):
                path_expre[j]=gse20853_exp[gse20853_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/164 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 164/164 [00:20<00:00,  7.91it/s]
# CPU times: total: 20.8 s
# Wall time: 20.7 s

# %%
# %%time
col_13213=gse13213_exp.columns.tolist()
col_13213.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_13213):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse13213_exp['geneName']):
                path_expre[j]=gse13213_exp[gse13213_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/117 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 117/117 [00:17<00:00,  6.88it/s]
# CPU times: total: 17 s
# Wall time: 17 s

# %%
# %%time
col_32863=gse32863_exp.columns.tolist()
col_32863.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_32863):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse32863_exp['geneName']):
                path_expre[j]=gse32863_exp[gse32863_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/116 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 116/116 [00:16<00:00,  6.87it/s]
# CPU times: total: 16.9 s
# Wall time: 16.9 s

# %%
# %%time
col_26939=gse26939_exp.columns.tolist()
col_26939.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_26939):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse26939_exp['geneName']):
                path_expre[j]=gse26939_exp[gse26939_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/102 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 102/102 [00:14<00:00,  7.06it/s]
# CPU times: total: 14.4 s
# Wall time: 14.4 s

# %%
# %%time
col_10072=gse10072_exp.columns.tolist()
col_10072.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_10072):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse10072_exp['geneName']):
                path_expre[j]=gse10072_exp[gse10072_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/107 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 107/107 [00:14<00:00,  7.35it/s]
# CPU times: total: 14.6 s
# Wall time: 14.6 s

# %%
# %%time
col_12667=gse12667_exp.columns.tolist()
col_12667.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_12667):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse12667_exp['geneName']):
                path_expre[j]=gse12667_exp[gse12667_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/75 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 75/75 [00:10<00:00,  6.93it/s]
# CPU times: total: 10.8 s
# Wall time: 10.8 s

# %%
# %%time
col_1037=gse1037_2088_exp.columns.tolist()
col_1037.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_1037):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse1037_2088_exp['geneName']):
                path_expre[j]=gse1037_2088_exp[gse1037_2088_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/87 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 87/87 [00:10<00:00,  7.93it/s]
# CPU times: total: 11 s
# Wall time: 11 s

# %%
# %%time
col_29016=gse29016_exp.columns.tolist()
col_29016.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_29016):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse29016_exp['geneName']):
                path_expre[j]=gse29016_exp[gse29016_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/72 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 72/72 [00:10<00:00,  6.86it/s]
# CPU times: total: 10.6 s
# Wall time: 10.5 s

# %%
# %%time
col_5843=gse5843_exp.columns.tolist()
col_5843.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_5843):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse5843_exp['geneName']):
                path_expre[j]=gse5843_exp[gse5843_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/48 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 48/48 [00:06<00:00,  7.19it/s]
# CPU times: total: 6.69 s
# Wall time: 6.68 s

# %%
# %%time
col_20875=gse20875_exp.columns.tolist()
col_20875.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_20875):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse20875_exp['geneName']):
                path_expre[j]=gse20875_exp[gse20875_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/36 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [00:05<00:00,  7.20it/s]
# CPU times: total: 5.03 s
# Wall time: 5 s

# %%
# %%time
col_2514=gse2514_exp.columns.tolist()
col_2514.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_2514):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse2514_exp['geneName']):
                path_expre[j]=gse2514_exp[gse2514_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/39 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 39/39 [00:04<00:00,  8.13it/s]
# CPU times: total: 4.78 s
# Wall time: 4.8 s

# %%
# %%time
col_17475=gse17475_exp.columns.tolist()
col_17475.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_17475):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse17475_exp['geneName']):
                path_expre[j]=gse17475_exp[gse17475_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/28 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:03<00:00,  7.33it/s]
# CPU times: total: 3.81 s
# Wall time: 3.82 s

# %%
# %%time
col_nm=nm_exp.columns.tolist()
col_nm.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_nm):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(nm_exp['geneName']):
                path_expre[j]=nm_exp[nm_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/96 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 96/96 [00:10<00:00,  9.15it/s]
# CPU times: total: 10.5 s
# Wall time: 10.5 s

# %%
# %%time
col_tcga_luad=tcga_luad_exp.columns.tolist()
col_tcga_luad.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_tcga_luad):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(tcga_luad_exp['geneName']):
                path_expre[j]=tcga_luad_exp[tcga_luad_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/576 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 576/576 [01:24<00:00,  6.79it/s]
# CPU times: total: 1min 24s
# Wall time: 1min 24s

# %%
# %%time
col_luad_test=luad_test_exp.columns.tolist()
col_luad_test.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_luad_test):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(luad_test_exp['geneName']):
                path_expre[j]=luad_test_exp[luad_test_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/169 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 169/169 [00:24<00:00,  6.80it/s]
# CPU times: total: 24.9 s
# Wall time: 24.8 s

# %% [markdown]
# ## NSCLC Formation

# %%
# %%time
col_1987=gse1987_exp.columns.tolist()
col_1987.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_1987):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse1987_exp['geneName']):
                path_expre[j]=gse1987_exp[gse1987_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/37 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 37/37 [00:04<00:00,  7.74it/s]
# CPU times: total: 4.81 s
# Wall time: 4.78 s

# %%
# %%time
col_4573=gse4573_exp.columns.tolist()
col_4573.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_4573):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse4573_exp['geneName']):
                path_expre[j]=gse4573_exp[gse4573_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/130 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 130/130 [00:18<00:00,  7.19it/s]
# CPU times: total: 18.2 s
# Wall time: 18.1 s

# %%
# %%time
col_8894=gse8894_exp.columns.tolist()
col_8894.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_8894):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse8894_exp['geneName']):
                path_expre[j]=gse8894_exp[gse8894_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/138 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 138/138 [00:20<00:00,  6.84it/s]
# CPU times: total: 20.3 s
# Wall time: 20.2 s

# %%
# %%time
col_9971=gse9971_exp.columns.tolist()
col_9971.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_9971):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse9971_exp['geneName']):
                path_expre[j]=gse9971_exp[gse9971_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/27 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 27/27 [00:03<00:00,  7.38it/s]
# CPU times: total: 3.7 s
# Wall time: 3.66 s

# %%
# %%time
col_10245=gse10245_exp.columns.tolist()
col_10245.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_10245):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse10245_exp['geneName']):
                path_expre[j]=gse10245_exp[gse10245_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/48 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 48/48 [00:06<00:00,  6.97it/s]
# CPU times: total: 6.89 s
# Wall time: 6.88 s

# %%
# %%time
col_11117=gse11117_exp.columns.tolist()
col_11117.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_11117):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse11117_exp['geneName']):
                path_expre[j]=gse11117_exp[gse11117_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/44 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 44/44 [00:06<00:00,  6.96it/s]
# CPU times: total: 6.36 s
# Wall time: 6.32 s

# %%
# %%time
col_14814=gse14814_exp.columns.tolist()
col_14814.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_14814):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse14814_exp['geneName']):
                path_expre[j]=gse14814_exp[gse14814_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/133 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 133/133 [00:18<00:00,  7.30it/s]
# CPU times: total: 18.2 s
# Wall time: 18.2 s

# %%
# %%time
col_16534=gse16534_exp.columns.tolist()
col_16534.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_16534):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse16534_exp['geneName']):
                path_expre[j]=gse16534_exp[gse16534_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/43 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 43/43 [00:06<00:00,  6.77it/s]
# CPU times: total: 6.41 s
# Wall time: 6.36 s

# %%
# %%time
col_18842=gse18842_exp.columns.tolist()
col_18842.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_18842):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse18842_exp['geneName']):
                path_expre[j]=gse18842_exp[gse18842_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/91 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 91/91 [00:13<00:00,  6.90it/s]
# CPU times: total: 13.2 s
# Wall time: 13.2 s

# %%
# %%time
col_19188=gse19188_exp.columns.tolist()
col_19188.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_19188):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse19188_exp['geneName']):
                path_expre[j]=gse19188_exp[gse19188_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/156 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 156/156 [00:22<00:00,  6.98it/s]
# CPU times: total: 22.4 s
# Wall time: 22.4 s

# %%
# %%time
col_19804=gse19804_exp.columns.tolist()
col_19804.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_19804):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse19804_exp['geneName']):
                path_expre[j]=gse19804_exp[gse19804_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/120 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:17<00:00,  6.97it/s]
# CPU times: total: 17.4 s
# Wall time: 17.2 s

# %%
# %%time
col_25326=gse25326_exp.columns.tolist()
col_25326.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_25326):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse25326_exp['geneName']):
                path_expre[j]=gse25326_exp[gse25326_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/85 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 85/85 [00:09<00:00,  9.18it/s]
# CPU times: total: 9.28 s
# Wall time: 9.26 s

# %%
# %%time
col_28571=gse28571_exp.columns.tolist()
col_28571.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_28571):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse28571_exp['geneName']):
                path_expre[j]=gse28571_exp[gse28571_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.97it/s]
# CPU times: total: 14.4 s
# Wall time: 14.3 s

# %%
# %%time
col_37745=gse37745_exp.columns.tolist()
col_37745.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_37745):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse37745_exp['geneName']):
                path_expre[j]=gse37745_exp[gse37745_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/196 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 196/196 [00:28<00:00,  6.95it/s]
# CPU times: total: 28.2 s
# Wall time: 28.2 s

# %%
# %%time
col_42127=gse42127_exp.columns.tolist()
col_42127.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_42127):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse42127_exp['geneName']):
                path_expre[j]=gse42127_exp[gse42127_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/176 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 176/176 [00:25<00:00,  6.87it/s]
# CPU times: total: 25.7 s
# Wall time: 25.6 s

# %%
# %%time
col_43458=gse43458_exp.columns.tolist()
col_43458.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_43458):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse43458_exp['geneName']):
                path_expre[j]=gse43458_exp[gse43458_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/110 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 110/110 [00:16<00:00,  6.84it/s]
# CPU times: total: 16.1 s
# Wall time: 16.1 s

# %%
# %%time
col_50081=gse50081_exp.columns.tolist()
col_50081.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_50081):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse50081_exp['geneName']):
                path_expre[j]=gse50081_exp[gse50081_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/181 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 181/181 [00:25<00:00,  6.96it/s]
# CPU times: total: 26 s
# Wall time: 26 s

# %% [markdown]
# ## LUSC Formation

# %%
# %%time
col_5828=gse5828_exp.columns.tolist()
col_5828.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_5828):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse5828_exp['geneName']):
                path_expre[j]=gse5828_exp[gse5828_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/59 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 59/59 [00:08<00:00,  7.21it/s]
# CPU times: total: 8.23 s
# Wall time: 8.18 s

# %%
# %%time
col_12472=gse12472_exp.columns.tolist()
col_12472.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_12472):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse12472_exp['geneName']):
                path_expre[j]=gse12472_exp[gse12472_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/63 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 63/63 [00:04<00:00, 13.41it/s]
# CPU times: total: 4.7 s
# Wall time: 4.7 s

# %%
# %%time
col_17710=gse17710_exp.columns.tolist()
col_17710.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_17710):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse17710_exp['geneName']):
                path_expre[j]=gse17710_exp[gse17710_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/51 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 51/51 [00:07<00:00,  7.04it/s]
# CPU times: total: 7.25 s
# Wall time: 7.25 s

# %%
# %%time
col_23822=gse23822_exp.columns.tolist()
col_23822.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_23822):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse23822_exp['geneName']):
                path_expre[j]=gse23822_exp[gse23822_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/56 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:08<00:00,  6.86it/s]
# CPU times: total: 8.27 s
# Wall time: 8.16 s

# %%
# %%time
col_74777=gse74777_exp.columns.tolist()
col_74777.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_74777):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(gse74777_exp['geneName']):
                path_expre[j]=gse74777_exp[gse74777_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/107 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 107/107 [00:15<00:00,  6.87it/s]
# CPU times: total: 15.6 s
# Wall time: 15.6 s

# %%
# %%time
col_tcga_lusc=tcga_lusc_exp.columns.tolist()
col_tcga_lusc.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_tcga_lusc):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(tcga_lusc_exp['geneName']):
                path_expre[j]=tcga_lusc_exp[tcga_lusc_exp['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/552 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 552/552 [01:21<00:00,  6.81it/s]
# CPU times: total: 1min 21s
# Wall time: 1min 21s

# %% [markdown]
# ## SKCM Formation

# %%
# %%time
col_skcm_train=skcm_exp_train.columns.tolist()
col_skcm_train.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_skcm_train):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(skcm_exp_train['geneName']):
                path_expre[j]=skcm_exp_train[skcm_exp_train['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                          | 0/469 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|████████████████████████████████████████████████████████████████████████████████| 469/469 [01:03<00:00,  7.43it/s]
# CPU times: total: 1min 3s
# Wall time: 1min 3s

# %%
# %%time
col_skcm_test=skcm_exp_test.columns.tolist()
col_skcm_test.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_skcm_test):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(skcm_exp_test['geneName']):
                path_expre[j]=skcm_exp_test[skcm_exp_test['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/40 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:05<00:00,  6.83it/s]
# CPU times: total: 5.92 s
# Wall time: 5.85 s

# %% [markdown]
# # LGG Formation

# %%
# %%time
col_lgg_train=lgg_exp_train.columns.tolist()
col_lgg_train.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_lgg_train):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(lgg_exp_train['geneName']):
                path_expre[j]=lgg_exp_train[lgg_exp_train['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/27 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 27/27 [00:03<00:00,  6.98it/s]
# CPU times: total: 3.86 s
# Wall time: 3.87 s

# %%
# %%time
col_lgg_test=lgg_exp_test.columns.tolist()
col_lgg_test.remove('geneName')
from tqdm import tqdm
import time
for sample in tqdm(col_lgg_test):
    #time.sleep(0.25)
    expre_mat=np.empty((40,46))
    for i in range(len(pathways)):
        pathway=np.array(pathways.iloc[i]).tolist()
        path_expre=[0 for r in range(46)]
        for j in range(len(pathway)):
            #path_expre=gse72904_exp[gse72904_exp['geneName'].isin(pathway)][sample].tolist()
            if pathway[j] in set(lgg_exp_test['geneName']):
                path_expre[j]=lgg_exp_test[lgg_exp_test['geneName']==pathway[j]][sample].values
            else:
                path_expre[j]=0
        #while len(path_expre)!=46:
         #   if len(path_expre)<46:
          #      path_expre.append(0)
        expre_mat[i]=path_expre
    list49=[0 for m in range(49)]
    list46=[0 for n in range(46)]
    for p in range(9):
        expre_mat=np.row_stack((expre_mat,list46))
    for q in range(3):
        expre_mat=np.column_stack((expre_mat,list49))
    expre_df=pd.DataFrame(expre_mat).T
    chunk1=expre_df.iloc[:,0].values.reshape(7,7)
    chunk2=expre_df.iloc[:,7].values.reshape(7,7)
    chunk3=expre_df.iloc[:,14].values.reshape(7,7)
    chunk4=expre_df.iloc[:,21].values.reshape(7,7)
    chunk5=expre_df.iloc[:,28].values.reshape(7,7)
    chunk6=expre_df.iloc[:,35].values.reshape(7,7)
    chunk7=expre_df.iloc[:,42].values.reshape(7,7)
    for c in range(1,7):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk1=np.concatenate([chunk1,block],axis=1)
    for c in range(8,14):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk2=np.concatenate([chunk2,block],axis=1)
    for c in range(15,21):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk3=np.concatenate([chunk3,block],axis=1)
    for c in range(22,28):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk4=np.concatenate([chunk4,block],axis=1)
    for c in range(29,35):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk5=np.concatenate([chunk5,block],axis=1)
    for c in range(36,42):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk6=np.concatenate([chunk6,block],axis=1)
    for c in range(43,49):
        block=expre_df.iloc[:,c].values.reshape(7,7)
        chunk7=np.concatenate([chunk7,block],axis=1)
    pathway_blocks=np.concatenate([chunk1,chunk2,chunk3,chunk4,chunk5,chunk6,chunk7],axis=0)
    np.save('data/IMG/{}.npy'.format(sample),pathway_blocks)
# Out:
#   0%|                                                                                           | 0/43 [00:00<?, ?it/s]<timed exec>:20: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 43/43 [00:06<00:00,  7.09it/s]
# CPU times: total: 6.08 s
# Wall time: 6.07 s

# %% [markdown]
# # Label formation

# %%
gse72904_clinical
# Out:
# 0          Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM1854797          F      88     None               None               None
# GSM1854798          F      70        1                  1               None
# GSM1854799          F      59        1                  1               None
# GSM1854800          M      57        1               None               None
# GSM1854801          F      72        1                  4                  0
# ...               ...     ...      ...                ...                ...
# GSM1855234          M      83        1                  1               None
# GSM1855235          F      75        1               None               None
# GSM1855236          M      75        1                  1               None
# GSM1855237          F      81        1                  1               None
# GSM1855238          F      73        1               None               None
#
# 0          Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM1854797      11010000               None                  None
# GSM1854798      11010000               None                  None
# GSM1854799      11010000               None                  None
# GSM1854800      11010000               None                  None
# GSM1854801      11010000               None                  None
# ...                  ...                ...                   ...
# GSM1855234      11010000               None                  None
# GSM1855235      11010000               None                  None
# GSM1855236      11010000               None                  None
# GSM1855237      11010000               None                  None
# GSM1855238      11010000               None                  None
#
# 0          Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                               ...
# GSM1854797          None                          NaN  ...       None
# GSM1854798          None                         42.0  ...         IV
# GSM1854799          None                         35.0  ...         II
# GSM1854800          None                         34.0  ...          I
# GSM1854801          None                         30.0  ...          I
# ...                  ...                          ...  ...        ...
# GSM1855234          None                         56.0  ...          I
# GSM1855235          None                         24.0  ...          I
# GSM1855236          None                         55.0  ...          I
# GSM1855237          None                          6.0  ...        III
# GSM1855238          None                         54.0  ...          I
#
# 0          Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM1854797         None      None                 1                 0
# GSM1854798         None      None                 0                 0
# GSM1854799            B      None                 0                 0
# GSM1854800            B      None                 0                 0
# GSM1854801            B      None                 0                 0
# ...                 ...       ...               ...               ...
# GSM1855234            B      None                 0                 1
# GSM1855235            A      None                 1                 0
# GSM1855236            B      None                 0                 0
# GSM1855237            A      None                 0                 0
# GSM1855238            A      None                 0                 1
#
# 0          Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GS
pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# TCGA.05.4244.01A.01R.1107.07               None             LR        8140/3
# TCGA.05.4249.01A.01R.1107.07               None             LR        8140/3
# TCGA.05.4250.01A.01R.1107.07               None             LR        8140/3
# TCGA.05.4382.01A.01R.1206.07               None             UL        8140/3
# TCGA.05.4384.01A.01R.1755.07               None             LR        8140/3
# ...                                         ...            ...           ...
# TCGA.NJ.A55O.01A.11R.A262.07               None             UR        8140/3
# TCGA.NJ.A55R.01A.11R.A262.07               None             UL        8140/3
# TCGA.NJ.A7XG.01A.12R.A39D.07               None             UL        8140/3
# TCGA.O1.A52J.01A.11R.A262.07               None             LL        8140/3
# TCGA.S2.AA1A.01A.12R.A39D.07               None             UR        8140/3
#
# [516 rows x 26 columns]

# %%
consortium_clinical
# Out:
# 0               Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status  \
# Sam_Name
# CL2004110909AA           F      55     None                  3
# CL2004111002AA           F      41     None                  3
# CL2004111003AA           M      47     None                  3
# CL20041110100AA          M      73     None                  4
# CL20041110102AA          F      63     None                  2
# ...                    ...     ...      ...                ...
# NCI_U133A_96L            M      74        1                  3
# NCI_U133A_97L            M      74        1                  4
# NCI_U133A_98L            F      80        1                  3
# NCI_U133A_99L            F      68        1                  3
# NCI_U133A_9L             F      73        1                  4
#
# 0               Pat_Packs_Per_Year Pat_Histology Pat_Adjuvant_Chemo  \
# Sam_Name
# CL2004110909AA                None      11010000                  0
# CL2004111002AA                None      11010000                  0
# CL2004111003AA                None      11010000                  1
# CL20041110100AA               None      11010000               None
# CL20041110102AA               None      11010000               None
# ...                            ...           ...                ...
# NCI_U133A_96L                 None      11010000                  0
# NCI_U133A_97L                 None      11010000                  0
# NCI_U133A_98L                 None      11010000                  1
# NCI_U133A_99L                 None      11010000                  1
# NCI_U133A_9L                  None      11010000                  0
#
# 0               Pat_Neoadjuvant_Chemo Pat_Radiation  \
# Sam_Name
# CL2004110909AA                   None             0
# CL2004111002AA                   None             0
# CL2004111003AA                   None             0
# CL20041110100AA                  None          None
# CL20041110102AA                  None          None
# ...                               ...           ...
# NCI_U133A_96L                    None             0
# NCI_U133A_97L                    None             0
# NCI_U133A_98L                    None             0
# NCI_U133A_99L                    None             1
# NCI_U133A_9L                     None             0
#
# 0                Pat_Overall_Survival_Months  ...  Pat_Stage Pat_Substage  \
# Sam_Name                                      ...
# CL2004110909AA                           110  ...    I_or_II         None
# CL2004111002AA                            98  ...    I_or_II         None
# CL2004111003AA                           110  ...    I_or_II         None
# CL20041110100AA                           66  ...    I_or_II         None
# CL20041110102AA                           29  ...         II         None
# ...                                      ...  ...        ...          ...
# NCI_U133A_96L                             62  ...    I_or_II         None
# NCI_U133A_97L                             64  ...          I         None
# NCI_U133A_98L                             85  ...         II         None
# NCI_U133A_99L                             47  ...    I_or_II         None
# NCI_U133A_9L                              75  ...        III         None
#
# 0               Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# CL2004110909AA          3              None              None
# CL2004111002AA          3              None              None
# CL2004111003AA          2              None              None
# CL20041110100AA         3              None              None
# CL20041110102AA         3              None              None
# ...                   ...               ...               ...
# NCI_U133A_96L           2              None              None
# NCI_U133A_97L           2              None              None
# NCI_U133A_98L           2              None              None
# NCI_U133A_99L           3              None              None
# NCI_U133A_9L            2              None              None
#
# 0               Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# CL2004110909AA                   None              None               None
# CL2004111002AA                   None              None               None
# CL2004111003AA                   None              None               None
# CL20041110100AA                  None              None               None
# CL20041110102AA                  None              None               None
# ...                               ...               ...                ...
# NCI_U133A_96L                    None              None               None
# NCI_U133A_97L                    None              None               None
# NCI_U133A_98L                    None              None               None
# NCI_U133A_99L                    None              None               None
# NCI_U133A_9L                     None              None               None
#
# 0               Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# CL2004110909AA            None        8140/3
# CL2004111002AA            None        8140/3
# CL2004111003AA            None        8140/3
# CL20041110100AA           None        8140/3
# CL20041110102AA           None        8140/3
# ...                        ...           ...
# NCI_U133A_96L             None        8140/3
# NCI_U133A_97L             None        8140/3
# NCI_U133A_98L             None        8140/3
# NCI_U133A_99L             None        8140/3
# NCI_U133A_9L              None        8140/3
#
# [442 rows x 26 columns]

# %%
gse41271_clinical
# Out:
# 0          Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM1012828          M      71        1                  1               None
# GSM1012829          M      68        1                  1               None
# GSM1012830          M      55        1                  1               None
# GSM1012831          M      81        1                  1               None
# GSM1012832          M      64        1                  1               None
# ...               ...     ...      ...                ...                ...
# GSM1013098          F      62        1                  4                  0
# GSM1013099          F      68        1                  4                  0
# GSM1013100          M    None        1                  4                  0
# GSM1013101          M      75        1                  1               None
# GSM1013102          F      61        1                  4                  0
#
# 0          Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM1012828      11010000               None                  None
# GSM1012829      11020000               None                  None
# GSM1012830      11010000               None                  None
# GSM1012831      11010000               None                  None
# GSM1012832      11010000               None                  None
# ...                  ...                ...                   ...
# GSM1013098      11010000               None                  None
# GSM1013099      11010000               None                  None
# GSM1013100      11010000               None                  None
# GSM1013101      12060000               None                  None
# GSM1013102      11010000               None                  None
#
# 0          Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                               ...
# GSM1012828          None                          8.0  ...        III
# GSM1012829          None                         70.0  ...        III
# GSM1012830          None                         11.0  ...        III
# GSM1012831          None                         10.0  ...         II
# GSM1012832          None                         35.0  ...          I
# ...                  ...                          ...  ...        ...
# GSM1013098          None                          7.0  ...        III
# GSM1013099          None                         17.0  ...         II
# GSM1013100          None                          NaN  ...         IV
# GSM1013101          None                          8.0  ...         II
# GSM1013102          None                         38.0  ...        III
#
# 0          Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM1012828            A      None              None              None
# GSM1012829            A      None              None              None
# GSM1012830            B      None              None              None
# GSM1012831            B      None              None              None
# GSM1012832            B      None              None              None
# ...                 ...       ...               ...               ...
# GSM1013098            A      None              None              None
# GSM1013099            B      None              None              None
# GSM1013100         None      None              None              None
# GSM1013101            B      None              None              None
# GSM1013102            A      None              None              None
#
# 0          Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM1012828                  None              None               None
# GSM1012829                  None              None               None
# GSM1012830                  None              None               None
# GSM1012831                  None              None               None
# GSM1012832                  None              None               None
# ...                          ...               ...                ...
# GSM1013098                  None              None               None
# GSM1013099                  None              None               None
# GSM1013100                  None              None               None
# GSM1013101                  None              None               None
# GSM1013102                  None              None               None
#
# 0          Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM1012828           None        8140/3
# GSM1012829           None        8070/3
# GSM1012830           None        8140/3
# GSM1012831           None        8140/3
# GSM1012832           None        8140/3
# ...                   ...           ...
# GSM1013098           None        8140/3
# GSM1013099           None        8140/3
# GSM1013100           None        8140/3
# GSM1013101           None        8560/3
# GSM1013102           None        8140/3
#
# [275 rows x 26 columns]

# %%
gse31210_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM773541          F      38        3                  1               None
# GSM773542          M      30        3                  1               None
# GSM773544          F      63        3                  4               None
# GSM773545          F      60        3                  4               None
# GSM773547          M      58        3                  1               None
# ...              ...     ...      ...                ...                ...
# GSM773776          M    None        3                  4               None
# GSM773782          M    None        3                  1               None
# GSM773783          M    None        3                  1               None
# GSM773784          M    None        3                  1               None
# GSM773785          F    None        3                  1               None
#
# 0         Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM773541      11010000                  0                  None
# GSM773542      11010000                  0                  None
# GSM773544      11010000                  0                  None
# GSM773545      11010000                  0                  None
# GSM773547      11010000                  0                  None
# ...                 ...                ...                   ...
# GSM773776      40000000               None                  None
# GSM773782      40000000               None                  None
# GSM773783      40000000               None                  None
# GSM773784      40000000               None                  None
# GSM773785      40000000               None                  None
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM773541             0                         25.0  ...         II
# GSM773542             0                         87.0  ...         II
# GSM773544             0                         79.0  ...         II
# GSM773545             0                         63.0  ...         II
# GSM773547             0                         10.0  ...         II
# ...                 ...                          ...  ...        ...
# GSM773776          None                          NaN  ...       None
# GSM773782          None                          NaN  ...       None
# GSM773783          None                          NaN  ...       None
# GSM773784          None                          NaN  ...       None
# GSM773785          None                          NaN  ...       None
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM773541         None      None                 0                 0
# GSM773542         None      None                 0                 0
# GSM773544         None      None                 0                 0
# GSM773545         None      None                 0                 0
# GSM773547         None      None                 0                 0
# ...                ...       ...               ...               ...
# GSM773776         None      None                 0                 0
# GSM773782         None      None                 0                 0
# GSM773783         None      None                 0                 0
# GSM773784         None      None                 0                 0
# GSM773785         None      None                 0                 0
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM773541                     1              None               None
# GSM773542                     1              None               None
# GSM773544                     1              None               None
# GSM773545                     1              None               None
# GSM773547                     1              None               None
# ...                         ...               ...                ...
# GSM773776                     0              None               None
# GSM773782                     0              None               None
# GSM773783                     0              None               None
# GSM773784                     0              None               None
# GSM773785                     0              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM773541           None        8140/3
# GSM773542           None        8140/3
# GSM773544           None        8140/3
# GSM773545           None        8140/3
# GSM773547           None        8140/3
# ...                  ...           ...
# GSM773776           None          None
# GSM773782           None          None
# GSM773783           None          None
# GSM773784           None          None
# GSM773785           None          None
#
# [209 rows x 26 columns]

# %%
pnas_clinical
# Out:
# 0              Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status  \
# Sam_Name
# CL2001031606AA       None    None     None               None
# CL2001031607AA       None    None     None               None
# CL2001031609AA       None    None     None               None
# CL2001031611AA       None    None     None               None
# CL2001031612AA       None    None     None               None
# ...                   ...     ...      ...                ...
# CL2001041714AA          F      70     None                  1
# CL2001041716AA          F      69     None                  1
# CL2001042501AA       None    None     None               None
# CL2001042505AA       None    None     None               None
# CL2001042506AA       None    None     None               None
#
# 0              Pat_Packs_Per_Year Pat_Histology Pat_Adjuvant_Chemo  \
# Sam_Name
# CL2001031606AA               None      11020000               None
# CL2001031607AA               None      12010000               None
# CL2001031609AA               None      12030000               None
# CL2001031611AA               None      11010000               None
# CL2001031612AA               None      11010000               None
# ...                           ...           ...                ...
# CL2001041714AA                100      11010000               None
# CL2001041716AA                 60      11010000               None
# CL2001042501AA               None      12030000               None
# CL2001042505AA               None      11010000               None
# CL2001042506AA               None      11010000               None
               None                  None
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM302996          None                         44.0  ...          I
# GSM302997          None                        109.0  ...          I
# GSM302998          None                         56.0  ...        III
# GSM302999          None                        107.0  ...         II
# GSM303000          None                         40.0  ...        III
# ...                 ...                          ...  ...        ...
# GSM303154          None                          NaN  ...       None
# GSM303155          None                          NaN  ...       None
# GSM303156          None                          NaN  ...       None
# GSM303157          None                          NaN  ...       None
# GSM303158          None                          NaN  ...       None
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM302996            B         3                 1                 0
# GSM302997            A         2                 0                 0
# GSM302998            A         2                 0                 0
# GSM302999            A         2                 0                 0
# GSM303000            A         1                 1                 0
# ...                ...       ...               ...               ...
# GSM303154         None      None              None              None
# GSM303155         None      None              None              None
# GSM303156         None      None              None              None
# GSM303157         None      None              None              None
# GSM303158         None      None              None              None
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM302996                  None                 0               None
# GSM302997                  None                 0               None
# GSM302998                  None                 1               None
# GSM302999                  None                 0               None
# GSM303000                  None                 1               None
# ...                         ...               ...                ...
# GSM303154                  None              None               None
# GSM303155                  None              None               None
# GSM303156                  None              None               None
# GSM303157                  None              None               None
# GSM303158                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM302996           None        8140/3
# GSM302997           None        8140/3
# GSM302998           None        8140/3
# GSM302999           None        8140/3
# GSM303000           None        8140/3
# ...                  ...           ...
# GSM303154           None          None
# GSM303155           None          None
# GSM303156           None          None
# GSM303157           None          None
# GSM303158           None          None
#
# [163 rows x 26 columns]

# %%
gse20853_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM521431       None    None        3               None               None
# GSM521432       None    None        3               None               None
# GSM521433       None    None        3               None               None
# GSM521434       None    None        3               None               None
# GSM521435       None    None        3               None               None
# ...              ...     ...      ...                ...                ...
# GSM521590       None    None        3               None               None
# GSM521591       None    None        3               None               None
# GSM521592       None    None        3               None               None
# GSM521593       None    None        3               None               None
# GSM521594       None    None        3               None               None
#
# 0         Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM521431      11010000               None                  None
# GSM521432      11010000               None                  None
# GSM521433      11010000               None                  None
# GSM521434      11010000               None                  None
# GSM521435      11010000               None                  None
# ...                 ...                ...                   ...
# GSM521590      11020000               None                  None
# GSM521591      11020000               None                  None
# GSM521592      11020000               None                  None
# GSM521593      11020000               None                  None
# GSM521594      11020000               None                  None
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM521431          None                          NaN  ...       None
# GSM521432          None                          NaN  ...       None
# GSM521433          None                          NaN  ...       None
# GSM521434          None                          NaN  ...       None
# GSM521435          None                          NaN  ...       None
# ...                 ...                          ...  ...        ...
# GSM521590          None                          NaN  ...       None
# GSM521591          None                          NaN  ...       None
# GSM521592          None                          NaN  ...       None
# GSM521593          None                          NaN  ...       None
# GSM521594          None                          NaN  ...       None
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM521431         None      None              None              None
# GSM521432         None      None              None              None
# GSM521433         None      None              None              None
# GSM521434         None      None              None              None
# GSM521435         None      None              None              None
# ...                ...       ...               ...               ...
# GSM521590         None      None              None              None
# GSM521591         None      None              None              None
# GSM521592         None      None              None              None
# GSM521593         None      None              None              None
# GSM521594         None      None              None              None
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM521431                  None              None               None
# GSM521432                  None              None               None
# GSM521433                  None              None               None
# GSM521434                  None              None               None
# GSM521435                  None              None               None
# ...                         ...               ...                ...
# GSM521590                  None              None               None
# GSM521591                  None              None               None
# GSM521592                  None              None               None
# GSM521593                  None              None               None
# GSM521594                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GS
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM813411           None        8140/3
# GSM813413           None        8140/3
# GSM813415           None        8140/3
# GSM813417           None        8140/3
# GSM813419           None        8140/3
# GSM813421           None        8140/3
# GSM813423           None        8140/3
# GSM813425           None        8140/3
# GSM813427           None        8140/3
# GSM813429           None        8140/3
# GSM813431           None        8140/3
# GSM813433           None        8140/3
# GSM813435           None        8140/3
# GSM813437           None        8140/3
# GSM813439           None        8140/3
# GSM813441           None        8140/3
# GSM813443           None        8140/3
# GSM813445           None        8140/3
# GSM813447           None        8140/3
# GSM813449           None        8140/3
# GSM813451           None        8140/3
# GSM813453           None        8140/3
# GSM813455           None        8140/3
# GSM813457           None        8140/3
# GSM813459           None        8140/3
# GSM813461           None        8140/3
# GSM813463           None        8140/3
# GSM813465           None        8140/3
# GSM813467           None        8140/3
# GSM813469           None        8140/3
# GSM813471           None        8140/3
# GSM813473           None        8140/3
# GSM813475           None        8140/3
# GSM813477           None        8140/3
# GSM813479           None        8140/3
# GSM813481           None        8140/3
# GSM813483           None        8140/3
# GSM813485           None        8140/3
# GSM813487           None        8140/3
# GSM813489           None        8140/3
# GSM813491           None        8140/3
# GSM813493           None        8140/3
# GSM813495           None        8140/3
# GSM813497           None        8140/3
# GSM813499           None        8140/3
# GSM813501           None        8140/3
# GSM813503           None        8140/3
# GSM813505           None        8140/3
# GSM813507           None        8140/3
# GSM813508           None        8140/3
# GSM813510           None        8140/3
# GSM813512           None        8140/3
# GSM813514           None        8140/3
# GSM813516           None        8140/3
# GSM813518           None        8140/3
# GSM813519           None        8140/3
# GSM813521           None        8140/3
# GSM813523           None        8140/3
# GSM813525           None        8140/3
#
# [59 rows x 26 columns]

# %%
gse26939_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM663284          M      68     None                  1               None
# GSM663285          M      68     None                  1               None
# GSM663286          M      55     None                  1               None
# GSM663287          F      79     None                  1               None
# GSM663288          F      75     None                  1               None
# ...              ...     ...      ...                ...                ...
# GSM663395          F      52     None                  1               None
# GSM663396          F      66     None                  1               None
# GSM663397          F      85     None                  1               None
# GSM663398          M      65     None                  1               None
# GSM663399          F      67     None                  4                  0
#
# 0         Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM663284      11010000               None                  None
# GSM663285      11010000               None                  None
# GSM663286      11010000               None                  None
# GSM663287      11010000               None                  None
# GSM663288      11010000               None                  None
# ...                 ...                ...                   ...
# GSM663395      11010000               None                  None
# GSM663396      11010000               None                  None
# GSM663397      11010000               None                  None
# GSM663398      11010000               None                  None
# GSM663399      11010000               None                  None
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM663284          None                         44.0  ...          I
# GSM663285          None                         18.0  ...       None
# GSM663286          None                          5.0  ...          I
# GSM663287          None                         13.0  ...          I
# GSM663288          None                          7.0  ...          I
# ...                 ...                          ...  ...        ...
# GSM663395          None                        126.0  ...          I
# GSM663396          None                         14.0  ...          I
# GSM663397          None                         37.0  ...          I
# GSM663398          None                        122.0  ...        III
# GSM663399          None                         95.0  ...          I
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM663284            A         3                 0                 0
# GSM663285         None         3              None              None
# GSM663286            A         3                 0                 0
# GSM663287            A         2                 0                 0
# GSM663288            B         3                 0                 0
# ...                ...       ...               ...               ...
# GSM663395            A         2              None                 0
# GSM663396            B         2              None                 0
# GSM663397            A         2              None                 0
# GSM663398            A         3              None                 0
# GSM663399            B         2                 0                 0
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM663284                  None                 1                  1
# GSM663285                  None              None               None
# GSM663286                  None                 0                  0
# GSM663287                  None                 0                  0
# GSM663288                  None                 1                  1
# ...                         ...               ...                ...
# GSM663395                  None                 0               None
# GSM663396                  None                 0               None
# GSM663397                  None                 0               None
# GSM663398                  None                 1               None
# GSM663399                  None                 0                  0
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM663284           None        8140/3
# GSM663285           None        8140/3
# GSM663286           None        8140/3
# GSM663287           None        8140/3
# GSM663288           None        8140/3
# ...                  ...           ...
# GSM663395           None        8140/3
# GSM663396           None        8140/3
# GSM663397           None        8140/3
# GSM663398           None        8140/3
# GSM663399           None        8140/3
#
# [102 rows x 26 columns]

# %%
gse10072_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM254625          M      69     None                  4                  0
# GSM254627          M      68     None                  3               None
# GSM254629          F      74     None                  4                  0
# GSM254630          M      75     None                  3               None
# GSM254631          M      67     None                  3               None
# ...              ...     ...      ...                ...                ...
# GSM254725          M      69     None                  2               None
# GSM254726          M      68     None                  4                  0
# GSM254728          F      72     None                  4                  0
# GSM254729          M      70     None                  3               None
# GSM254731          M      63     None                  3               None
#
# 0         Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM254625      11010000               None                  None
# GSM254627      11010000               None                  None
# GSM254629      11010000               None                  None
# GSM254630      11010000               None                  None
# GSM254631      11010000               None                  None
# ...                 ...                ...                   ...
# GSM254725      40000000               None                  None
# GSM254726      11010000               None                  None
# GSM254728      11010000               None                  None
# GSM254729      11010000               None                  None
# GSM254731      40000000               None                  None
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM254625          None                          NaN  ...         II
# GSM254627          None                          NaN  ...         II
# GSM254629          None                          NaN  ...          I
# GSM254630          None                          NaN  ...         II
# GSM254631          None                          NaN  ...        III
# ...                 ...                          ...  ...        ...
# GSM254725          None                          NaN  ...         II
# GSM254726          None                          NaN  ...          I
# GSM254728          None                          NaN  ...          I
# GSM254729          None                          NaN  ...         II
# GSM254731          None                          NaN  ...         II
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM254625            B      None              None              None
# GSM254627            B      None              None              None
# GSM254629            B      None              None              None
# GSM254630            A      None              None              None
# GSM254631            A      None              None              None
# ...                ...       ...               ...               ...
# GSM254725            A      None              None              None
# GSM254726            B      None              None              None
# GSM254728            A      None              None              None
# GSM254729            B      None              None              None
# GSM254731            B      None              None              None
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM254625                  None              None               None
# GSM254627                  None              None               None
# GSM254629                  None              None               None
# GSM254630                  None              None               None
# GSM254631                  None              None               None
# ...                         ...               ...                ...
# GSM254725                  None              None               None
# GSM254726                  None              None               None
# GSM254728                  None              None               None
# GSM254729                  None              None               None
# GSM254731                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM254625           None        8140/3
# GSM254627           None        8140/3
# GSM254629           None        8140/3
# GSM254630           None        8140/3
# GSM254631           None        8140/3
# ...                  ...           ...
# GSM254725           None          None
# GSM254726           None        8140/3
# GSM254728           None        8140/3
# GSM254729           None        8140/3
# GSM254731           None          None
#
# [74 rows x 26 columns]

# %%
gse12667_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM318073          F      75        2                  3                 45
# GSM318074          F    None        1                  2               None
# GSM318075          M    None        1                  2               None
# GSM318076          M    None        1                  2               None
# GSM318077          F    None        1                  2               None
# ...              ...     ...      ...                ...                ...
# GSM318143          F      35        2                  4                  0
# GSM318144          M    None        1               None               None
# GSM318145          M      45        1                  4                  0
# GSM318146          F      85        1               None               None
# GSM318147          F      75        1               None               None
#
# 0         Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM318073      11010000               None                  None
# GSM318074      11010000               None                  None
# GSM318075      11010000               None                  None
# GSM318076      11010000               None                  None
# GSM318077      11010000               None                  None
# ...                 ...                ...                   ...
# GSM318143      11010000               None                  None
# GSM318144      11010000               None                  None
# GSM318145      11010000               None                  None
# GSM318146      11010000               None                  None
# GSM318147      11010000               None                  None
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM318073          None                          NaN  ...          I
# GSM318074          None                          NaN  ...       None
# GSM318075          None                          NaN  ...       None
# GSM318076          None                          NaN  ...       None
# GSM318077          None                          NaN  ...       None
# ...                 ...                          ...  ...        ...
# GSM318143          None                          NaN  ...         IV
# GSM318144          None                          NaN  ...       None
# GSM318145          None                          NaN  ...        III
# GSM318146          None                          NaN  ...          I
# GSM318147          None                          NaN  ...         II
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM318073            B         3              None              None
# GSM318074         None      None              None              None
# GSM318075         None      None              None              None
# GSM318076         None      None              None              None
# GSM318077         None      None              None              None
# ...                ...       ...               ...               ...
# GSM318143         None      None              None              None
# GSM318144         None      None              None              None
# GSM318145            A         2              None              None
# GSM318146            A         2              None              None
# GSM318147            B         3              None              None
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM318073                  None              None               None
# GSM318074                  None              None               None
# GSM318075                  None              None               None
# GSM318076                  None              None               None
# GSM318077                  None              None               None
# ...                         ...               ...                ...
# GSM318143                  None              None               None
# GSM318144                  None              None               None
# GSM318145                  None              None               None
# GSM318146                  None              None               None
# GSM318147                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM318073           None        8140/3
# GSM318074           None        8140/3
# GSM318075           None        8140/3
# GSM318076           None        8140/3
# GSM318077           None        8140/3
# ...                  ...           ...
# GSM318143           None        8140/3
# GSM318144           None        8140/3
# GSM318145           None        8140/3
# GSM318146           None        8140/3
# GSM318147           None        8140/3
#
# [75 rows x 26 columns]

# %%
gse1037_2088_clinical
# Out:
# 0        Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM16567          M      76        3                  1                 25
# GSM17287       None    None        3               None               None
# GSM17288       None    None        3               None               None
# GSM17289          M      75        3               None               None
# GSM17290          M      62        3               None               None
# ...             ...     ...      ...                ...                ...
# GSM37806       None    None        3               None               None
# GSM37807       None    None        3               None               None
# GSM37808       None    None        3               None               None
# GSM37809       None    None        3               None               None
# GSM37810       None    None        3               None               None
#
# 0        Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo Pat_Radiation  \
# Sam_Name
# GSM16567      11010000               None                  None          None
# GSM17287      40000000               None                  None          None
# GSM17288      40000000               None                  None          None
# GSM17289      40000000               None                  None          None
# GSM17290      40000000               None                  None          None
# ...                ...                ...                   ...           ...
# GSM37806      11010000               None                  None          None
# GSM37807      11010000               None                  None          None
# GSM37808      11010000               None                  None          None
# GSM37809      11010000               None                  None          None
# GSM37810      11010000               None                  None          None
#
# 0         Pat_Overall_Survival_Months  ...  Pat_Stage Pat_Substage Pat_Grade  \
# Sam_Name                               ...
# GSM16567                         41.0  ...          I         None         1
# GSM17287                          NaN  ...       None         None      None
# GSM17288                          NaN  ...       None         None      None
# GSM17289                          NaN  ...       None         None      None
# GSM17290                          NaN  ...       None         None      None
# ...                               ...  ...        ...          ...       ...
# GSM37806                          NaN  ...       None         None      None
# GSM37807                          NaN  ...       None         None      None
# GSM37808                          NaN  ...       None         None      None
# GSM37809                          NaN  ...       None         None      None
# GSM37810                          NaN  ...       None         None      None
#
# 0        Pat_EGFR_mutation Pat_KRAS_mutation Pat_ALK_translocation  \
# Sam_Name
# GSM16567              None              None                  None
# GSM17287              None              None                  None
# GSM17288              None              None                  None
# GSM17289              None              None                  None
# GSM17290              None              None                  None
# ...                    ...               ...                   ...
# GSM37806              None              None                  None
# GSM37807              None              None                  None
# GSM37808              None              None                  None
# GSM37809              None              None                  None
# GSM37810              None              None                  None
#
# 0        Pat_TP53_mutation Pat_STK11_mutation Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM16567              None               None             LL        8140/3
# GSM17287              None               None           None          None
# GSM17288              None               None           None          None
# GSM17289              None               None           None          None
# GSM17290              None               None           None          None
# ...                    ...                ...            ...           ...
# GSM37806              None               None           None        8140/3
# GSM37807              None               None           None        8140/3
# GSM37808              None               None           None        8140/3
# GSM37809              None               None           None        8140/3
# GSM37810              None               None           None        8140/3
#
# [87 rows x 26 columns]

# %%
gse29016_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM718902          F      74     None               None               None
# GSM718903          M      64     None                  1               None
# GSM718904          F      74     None               None               None
# GSM718905          F      52     None                  1               None
# GSM718906          F      47     None                  1               None
# ...              ...     ...      ...                ...                ...
# GSM718969          F      70     None                  4                  0
# GSM718970          F      76     None                  1               None
# GSM718971          M      64     None                  1               None
# GSM718972          F      56     None                  1               None
# GSM718973          F      65     None                  1               None
#
# 0         Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM718902      12010000               None                  None
# GSM718903      11010000               None                  None
# GSM718904      11010000               None                  None
# GSM718905      11010000               None                  None
# GSM718906      11010000               None                  None
# ...                 ...                ...                   ...
# GSM718969      11010000               None                  None
# GSM718970      12020000               None                  None
# GSM718971      12010000               None                  None
# GSM718972      12010000               None                  None
# GSM718973      12020000               None                  None
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM718902          None                          4.0  ...          I
# GSM718903          None                          4.0  ...        III
# GSM718904          None                          1.0  ...          I
# GSM718905          None                          5.0  ...         II
# GSM718906          None                         10.0  ...          I
# ...                 ...                          ...  ...        ...
# GSM718969          None                          9.0  ...          I
# GSM718970          None                          6.0  ...          I
# GSM718971          None                          NaN  ...       None
# GSM718972          None                          NaN  ...       None
# GSM718973          None                          3.0  ...          I
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM718902            B      None                 0                 0
# GSM718903            A      None                 0                 0
# GSM718904            A      None                 1                 0
# GSM718905            B      None                 0                 1
# GSM718906            B      None                 0                 0
# ...                ...       ...               ...               ...
# GSM718969            A      None                 0                 0
# GSM718970            B      None                 0                 0
# GSM718971         None      None              None              None
# GSM718972         None      None              None              None
# GSM718973            A      None                 0                 0
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM718902                  None              None               None
# GSM718903                  None              None               None
# GSM718904                  None              None               None
# GSM718905                  None              None               None
# GSM718906                  None              None               None
# ...                         ...               ...                ...
# GSM718969                  None              None               None
# GSM718970                  None              None               None
# GSM718971                  None              None               None
# GSM718972                  None              None               None
# GSM718973                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM718902           None        8041/3
# GSM718903           None        8140/3
# GSM718904           None        8140/3
# GSM718905           None        8140/3
# GSM718906           None        8140/3
# ...                  ...           ...
# GSM718969           None        8140/3
# GSM718970           None        8013/3
# GSM718971           None        8041/3
# GSM718972           None        8041/3
# GSM718973           None        8013/3
#
# [72 rows x 26 columns]

# %%
nm_clinical
# Out:
# 0        Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# AD10              M      65     None                  1                 60
# AD2               F      66     None                  1                 48
# AD3               F      60     None                  1               None
# AD5               F      62     None                  1               None
# AD6               M      66     None               None               None
# ...             ...     ...      ...                ...                ...
# LN71           None    None     None               None               None
# LN72B          None    None     None               None               None
# LN73           None    None     None               None               None
# LN74           None    None     None               None               None
# LN75           None    None     None               None               None
#
# 0        Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo Pat_Radiation  \
# Sam_Name
# AD10          11010000                  0                  None             0
# AD2           11010000                  0                  None             0
# AD3           11010000                  0                  None             0
# AD5           11010000                  0                  None             0
# AD6           11010000                  0                  None             0
# ...                ...                ...                   ...           ...
# LN71          11010000               None                  None          None
# LN72B         11010000               None                  None          None
# LN73          11010000               None                  None          None
# LN74          11010000               None                  None          None
# LN75          11010000               None                  None          None
#
# 0         Pat_Overall_Survival_Months  ...  Pat_Stage Pat_Substage Pat_Grade  \
# Sam_Name                               ...
# AD10                             84.0  ...          I         None         2
# AD2                              92.0  ...          I         None         3
# AD3                              94.0  ...          I         None         2
# AD5                             108.0  ...          I         None         1
# AD6                              35.0  ...          I         None         1
# ...                               ...  ...        ...          ...       ...
# LN71                              NaN  ...       None         None      None
# LN72B                             NaN  ...       None         None      None
# LN73                              NaN  ...       None         None      None
# LN74                              NaN  ...       None         None      None
# LN75                              NaN  ...       None         None      None
#
# 0        Pat_EGFR_mutation Pat_KRAS_mutation Pat_ALK_translocation  \
# Sam_Name
# AD10                  None              None                  None
# AD2                   None                 0                  None
# AD3                   None                 0                  None
# AD5                   None                 1                  None
# AD6                   None                 1                  None
# ...                    ...               ...                   ...
# LN71                  None              None                  None
# LN72B                 None              None                  None
# LN73                  None              None                  None
# LN74                  None              None                  None
# LN75                  None              None                  None
#
# 0        Pat_TP53_mutation Pat_STK11_mutation Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# AD10                  None               None           None        8140/3
# AD2                   None               None           None        8140/3
# AD3                   None               None           None        8140/3
# AD5                   None               None           None        8140/3
# AD6                   None               None           None        8140/3
# ...                    ...                ...            ...           ...
# LN71                  None               None           None        8140/3
# LN72B                 None               None           None        8140/3
# LN73                  None               None           None        8140/3
# LN74                  None               None           None        8140/3
# LN75                  None               None           None        8140/3
#
# [96 rows x 26 columns]

# %%
gse5843_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM135983          F      57     None                  2                 15
# GSM135984          F      43     None                  2                 28
# GSM135985          M      36     None                  2                 30
# GSM135986          M      70     None                  2                120
# GSM135987          M      51     None                  2                 30
# GSM135988          M      60     None                  2                 41
# GSM135990          M      46     None                  2                 32
# GSM135991          F      55     None                  2                 38
# GSM135992          M      71     None                  2                 37
# GSM135993          M      60     None                  2                 30
#
# 0         Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                              ...
# GSM135983             0                          125  ...          I
# GSM135984             0                          124  ...          I
# GSM135985             0                          169  ...          I
# GSM135986             0                          184  ...          I
# GSM135987             0                          155  ...          I
# GSM135988             0                          148  ...          I
# GSM135990             0                          133  ...          I
# GSM135991             0                           83  ...          I
# GSM135992             0                           69  ...          I
# GSM135993             0                          114  ...          I
# GSM135994             0                           93  ...          I
# GSM135995             0                           70  ...          I
# GSM135996             0                           71  ...          I
# GSM135997             0                           70  ...          I
# GSM135998             0                           67  ...          I
# GSM135999             0                           67  ...          I
# GSM136000             0                           71  ...          I
# GSM136001             0                           58  ...          I
# GSM136002             0                           56  ...          I
# GSM136003             0                           54  ...          I
# GSM136004             0                           53  ...          I
# GSM136005             0                           51  ...          I
# GSM136006             0                           53  ...          I
# GSM136007             0                           46  ...          I
# GSM136008             0                           44  ...          I
# GSM136009             0                          164  ...          I
# GSM136010             0                            7  ...          I
# GSM136011             0                           24  ...          I
# GSM136012             0                           22  ...          I
# GSM136013             0                           55  ...          I
# GSM136014             0                            8  ...          I
# GSM136015             0                           25  ...         II
# GSM136016             0                            4  ...          I
# GSM136017             0                           30  ...          I
# GSM136018             0                           14  ...          I
# GSM136019             0                           14  ...          I
# GSM136020             0                           14  ...          I
# GSM136021             0                           15  ...          I
# GSM136022             0                           64  ...          I
# GSM136023             0                           26  ...          I
# GSM136024             0                           26  ...          I
# GSM136025             0                           25  ...          I
# GSM136026             0                           26  ...          I
# GSM136027             0                            8  ...         II
# GSM136028             0                           13  ...          I
# GSM136029             0                           27  ...          I
# GSM136030             0                           11  ...          I
# GSM136031             0                           34  ...          I
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM135983            B         2              None              None
# GSM135984            A         1              None              None
# GSM135985            A         1              None              None
# GSM135986            A         1              None              None
# GSM135987            A         1              None              None
# GSM135988            B         1              None              None
# GSM135990            B         3              None              None
# GSM135991            B         2              None              None
# GSM135992            A         3              None              None
# GSM135993            A         1              None              None
# GSM135994            A         3              None              None
# GSM135995            B         2              None              None
# GSM135996            A         3              None              None
# GSM135997            B         3              None              None
# GSM135998            A         3              None              None
# GSM135999            A         2              None              None
# GSM136000            A         3              None              None
# GSM136001            B         3              None              None
# GSM136002            B         2              None              None
# GSM136003            A         3              None              None
# GSM136004            B         1              None              None
# GSM136005            B         3              None              None
# GSM136006            A         1              None              None
# GSM136007            B         2              None              None
# GSM136008            B         1              None              None
# GSM136009            B         1              None              None
# GSM136010            B         3              None              None
# GSM136011            B         1              None              None
# GSM136012            B         2              None              None
# GSM136013            B         3              None              None
# GSM136014            B         2              None              None
# GSM136015            B         2              None              None
# GSM136016            B         3              None              None
# GSM136017            A         2              None              None
# GSM136018            A         2              None              None
# GSM136019            B         1              None              None
# GSM136020            B         3              None              None
# GSM136021            B         2              None              None
# GSM136022            B         3              None              None
# GSM136023            B         3              None              None
# GSM136024            B         2              None              None
# GSM136025            A         2              None              None
# GSM136026            B         3              None              None
# GSM136027            B         3              None              None
# GSM136028            B         1              None              None
# GSM136029            B         1              None              None
# GSM136030            B         2              None              None
# GSM136031            B         3              None              None
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM135983                  None              None               None
# GSM135984                  None              None               None
# GSM135985                  None              None               None
# GSM135986                  None              None               None
# GSM135987                  None              None               None
# GSM135988                  None              None               None
# GSM135990                  None              None               None
# GSM135991                  None              None               None
# GSM135992                  None              None               None
# GSM135993                  None              None               None
# GSM135994                  None              None               None
# GSM135995                  None              None               None
# GSM135996                  None              None               None
# GSM135997                  None              None               None
# GSM135998                  None              None               None
# GSM135999                  None              None               None
# GSM136000                  None              None               None
# GSM136001                  None              None               None
# GSM136002                  None              None               None
# GSM136003                  None              None               None
# GSM136004                  None              None               None
# GSM136005                  None              None               None
# GSM136006                  None              None               None
# GSM136007                  None              None               None
# GSM136008                  None              None               None
# GSM136009                  None              None               None
# GSM136010                  None              None               None
# GSM136011                  None              None               None
# GSM136012                  None              None               None
# GSM136013                  None              None               None
# GSM136014                  None              None               None
# GSM136015                  None              None               None
# GSM136016                  None              None               None
# GSM136017                  None              None               None
# GSM136018                  None              None               None
# GSM136019                  None              None               None
# GSM136020                  None              None               None
# GSM136021                  None              None               None
# GSM136022                  None              None               None
# GSM136023                  None              None               None
# GSM136024                  None              None               None
# GSM136025                  None              None               None
# GSM136026                  None              None               None
# GSM136027                  None              None               None
# GSM136028                  None              None               None
# GSM136029                  None              None               None
# GSM136030                  None              None               None
# GSM136031                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM135983           None        8140/3
# GSM135984           None        8140/3
# GSM135985           None        8140/3
# GSM135986           None        8140/3
# GSM135987           None        8140/3
# GSM135988           None        8140/3
# GSM135990           None        8140/3
# GSM135991           None        8140/3
# GSM135992           None        8140/3
# GSM135993           None        8140/3
# GSM135994           None        8140/3
# GSM135995           None        8140/3
# GSM135996           None        8140/3
# GSM135997           None        8140/3
# GSM135998           None        8140/3
# GSM135999           None        8140/3
# GSM136000           None        8140/3
# GSM136001           None        8140/3
# GSM136002           None        8140/3
# GSM136003           None        8140/3
# GSM136004           None        8140/3
# GSM136005           None        8140/3
# GSM136006           None        8140/3
# GSM136007           None        8140/3
# GSM136008           None        8140/3
# GSM136009           None        8140/3
# GSM136010           None        8140/3
# GSM136011           None        8140/3
# GSM136012           None        8140/3
# GSM136013           None        8140/3
# GSM136014           None        8140/3
# GSM136015           None        8140/3
# GSM136016           None        8140/3
# GSM136017           None        8140/3
# GSM136018           None        8140/3
# GSM136019           None        8140/3
# GSM136020           None        8140/3
# GSM136021           None        8140/3
# GSM136022           None        8140/3
# GSM136023           None        8140/3
# GSM136024           None        8140/3
# GSM136025           None        8140/3
# GSM136026           None        8140/3
# GSM136027           None        8140/3
# GSM136028           None        8140/3
# GSM136029           None        8140/3
# GSM136030           None        8140/3
# GSM136031           None        8140/3
#
# [48 rows x 26 columns]

# %%
gse20875_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GS
# GSM529606          None                          NaN  ...          I
# GSM529607          None                          NaN  ...         II
# GSM529608          None                          NaN  ...        III
# GSM529609          None                          NaN  ...        III
# GSM529610          None                          NaN  ...        III
# GSM529611          None                          NaN  ...          I
# GSM529612          None                          NaN  ...         II
# GSM529613          None                          NaN  ...         II
# GSM529614          None                          NaN  ...         IV
# GSM529615          None                          NaN  ...          I
# GSM529616          None                          NaN  ...          I
# GSM529617          None                          NaN  ...         IV
#
# 0         Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM135990            B         3              None              None
# GSM135991            B         2              None              None
# GSM135992            A         3              None              None
# GSM135993            A         1              None              None
# GSM135994            A         3              None              None
# GSM135999            A         2              None              None
# GSM136001            B         3              None              None
# GSM136004            B         1              None              None
# GSM136005            B         3              None              None
# GSM136006            A         1              None              None
# GSM136010            B         3              None              None
# GSM136011            B         1              None              None
# GSM136012            B         2              None              None
# GSM136016            B         3              None              None
# GSM136018            A         2              None              None
# GSM136019            B         1              None              None
# GSM136021            B         2              None              None
# GSM136022            B         3              None              None
# GSM136024            B         2              None              None
# GSM136028            B         1              None              None
# GSM136030            B         2              None              None
# GSM136031            B         3              None              None
# GSM529604            B      None              None              None
# GSM529605            B      None              None              None
# GSM529606            B      None              None              None
# GSM529607            A      None              None              None
# GSM529608            A      None              None              None
# GSM529609            A      None              None              None
# GSM529610            A      None              None              None
# GSM529611            A      None              None              None
# GSM529612            B      None              None              None
# GSM529613            B      None              None              None
# GSM529614         None      None              None              None
# GSM529615            A      None              None              None
# GSM529616            B      None              None              None
# GSM529617         None      None              None              None
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM135990                  None              None               None
# GSM135991                  None              None               None
# GSM135992                  None              None               None
# GSM135993                  None              None               None
# GSM135994                  None              None               None
# GSM135999                  None              None               None
# GSM136001                  None              None               None
# GSM136004                  None              None               None
# GSM136005                  None              None               None
# GSM136006                  None              None               None
# GSM136010                  None              None               None
# GSM136011                  None              None               None
# GSM136012                  None              None               None
# GSM136016                  None              None               None
# GSM136018                  None              None               None
# GSM136019                  None              None               None
# GSM136021                  None              None               None
# GSM136022                  None              None               None
# GSM136024                  None              None               None
# GSM136028                  None              None               None
# GSM136030                  None              None               None
# GSM136031                  None              None               None
# GSM529604                  None              None               None
# GSM529605                  None              None               None
# GSM529606                  None              None               None
# GSM529607                  None              None               None
# GSM529608                  None              None               None
# GSM529609                  None              None               None
# GSM529610                  None              None               None
# GSM529611                  None              None               None
# GSM529612                  None              None               None
# GSM529613                  None              None               None
# GSM529614                  None              None               None
# GSM529615                  None              None               None
# GSM529616                  None              None               None
# GSM529617                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM135990           None        8140/3
# GSM135991           None        8140/3
# GSM135992           None        8140/3
# GSM135993           None        8140/3
# GSM135994           None        8140/3
# GSM135999           None        8140/3
# GSM136001           None        8140/3
# GSM136004           None        8140/3
# GSM136005           None        8140/3
# GSM136006           None        8140/3
# GSM136010           None        8140/3
# GSM136011           None        8140/3
# GSM136012           None        8140/3
# GSM136016           None        8140/3
# GSM136018           None        8140/3
# GSM136019           None        8140/3
# GSM136021           None        8140/3
# GSM136022           None        8140/3
# GSM136024           None        8140/3
# GSM136028           None        8140/3
# GSM136030           None        8140/3
# GSM136031           None        8140/3
# GSM529604           None        8140/3
# GSM529605           None        8140/3
# GSM529606           None        8140/3
# GSM529607           None        8140/3
# GSM529608           None        8140/3
# GSM529609           None        8140/3
# GSM529610           None        8140/3
# GSM529611           None        8140/3
# GSM529612           None        8140/3
# GSM529613           None        8140/3
# GSM529614           None        8140/3
# GSM529615           None        8140/3
# GSM529616           None        8140/3
# GSM529617           None        8140/3
#
# [36 rows x 26 columns]

# %%
gse2514_clinical
# Out:
# 0        Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM36757       None    None     None               None               None
# GSM36759       None    None     None               None               None
# GSM36761       None    None     None               None               None
# GSM36763       None    None     None               None               None
# GSM36765       None    None     None               None               None
# GSM36767       None    None     None               None               None
# GSM36769       None    None     None               None               None
# GSM36771       None    None     None               None               None
# GSM36773       None    None     None               None               None
# GSM36775       None    None     None               None               None
#
# 0        Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo Pat_Radiation  \
# Sam_Name
# GSM36757      11010000               None                  None          None
# GSM36759      11010000               None                  None          None
# GSM36761      11010000               None                  None          None
# GSM36763      11010000               None                  None          None
# GSM36765      11010000               None                  None          None
# GSM36767      11010000               None                  None          None
# GSM36769      11010000               None                  None          None
# GSM36771      11010000               None                  None          None
# GSM36773      11010000               None                  None          None
# GSM36775      11010000               None                  None          None
#
# 0         Pat_Overall_Survival_Months  ...  Pat_Stage Pat_Substage Pat_Grade  \
# Sam_Name                               ...
# GSM36757                          NaN  ...       None         None      None
# GSM36759                          NaN  ...       None         None      None
# GSM36761                          NaN  ...       None         None      None
# GSM36763                          NaN  ...       None         None      None
# GSM36765                          NaN  ...       None         None      None
# GSM36767                          NaN  ...       None         None      None
# GSM36769                          NaN  ...       None         None      None
# GSM36771                          NaN  ...       None         None      None
# GSM36773                          NaN  ...       None         None      None
# GSM36775                          NaN  ...       None         None      None
#
# 0        Pat_EGFR_mutation Pat_KRAS_mutation Pat_ALK_translocation  \
# Sam_Name
# GSM36757              None              None                  None
# GSM36759              None              None                  None
# GSM36761              None              None                  None
# GSM36763              None              None                  None
# GSM36765              None              None                  None
# GSM36767              None              None                  None
# GSM36769              None              None                  None
# GSM36771              None              None                  None
# GSM36773              None              None                  None
# GSM36775              None              None                  None
#
# 0        Pat_TP53_mutation Pat_STK11_mutation Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM36757              None               None           None        8140/3
# GSM36759              None               None           None        8140/3
# GSM36761              None               None           None        8140/3
# GSM36763              None               None           None        8140/3
# GSM36765              None               None           None        8140/3
# GSM36767              None               None           None        8140/3
# GSM36769              None               None           None        8140/3
# GSM36771              None               None           None        8140/3
# GSM36773              None               None           None        8140/3
# GSM36775              None               None           None        8140/3
#
# [10 rows x 26 columns]

# %%
gse17475_clinical
# Out:
# 0         Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GS
pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM435857         None         2              None              None
# GSM435858         None         3              None              None
# GSM435859         None         2              None              None
# GSM435860         None         2              None              None
# GSM435861         None         3              None              None
# GSM435862         None         2              None              None
# GSM435863         None         3              None              None
# GSM435864         None         2              None              None
# GSM435865         None         3              None              None
# GSM435866         None         2              None              None
# GSM435867         None         2              None              None
# GSM435868         None         1              None              None
# GSM435869         None         1              None              None
# GSM435870         None         2              None              None
# GSM435871         None         3              None              None
# GSM435872         None         2              None              None
# GSM435873         None         2              None              None
# GSM435874         None         2              None              None
# GSM435875         None         3              None              None
# GSM435876         None         3              None              None
# GSM435877         None         2              None              None
# GSM435878         None         3              None              None
# GSM435879         None         2              None              None
# GSM435880         None         2              None              None
# GSM435881         None         3              None              None
# GSM435882         None         2              None              None
# GSM435883         None         3              None              None
# GSM435884         None         1              None              None
#
# 0         Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM435857                  None              None               None
# GSM435858                  None              None               None
# GSM435859                  None              None               None
# GSM435860                  None              None               None
# GSM435861                  None              None               None
# GSM435862                  None              None               None
# GSM435863                  None              None               None
# GSM435864                  None              None               None
# GSM435865                  None              None               None
# GSM435866                  None              None               None
# GSM435867                  None              None               None
# GSM435868                  None              None               None
# GSM435869                  None              None               None
# GSM435870                  None              None               None
# GSM435871                  None              None               None
# GSM435872                  None              None               None
# GSM435873                  None              None               None
# GSM435874                  None              None               None
# GSM435875                  None              None               None
# GSM435876                  None              None               None
# GSM435877                  None              None               None
# GSM435878                  None              None               None
# GSM435879                  None              None               None
# GSM435880                  None              None               None
# GSM435881                  None              None               None
# GSM435882                  None              None               None
# GSM435883                  None              None               None
# GSM435884                  None              None               None
#
# 0         Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM435857           None        8140/3
# GSM435858           None        8140/3
# GSM435859           None        8140/3
# GSM435860           None        8140/3
# GSM435861           None        8140/3
# GSM435862           None        8140/3
# GSM435863           None        8140/3
# GSM435864           None        8140/3
# GSM435865           None        8140/3
# GSM435866           None        8140/3
# GSM435867           None        8140/3
# GSM435868           None        8140/3
# GSM435869           None        8140/3
# GSM435870           None        8140/3
# GSM435871           None        8140/3
# GSM435872           None        8140/3
# GSM435873           None        8140/3
# GSM435874           None        8140/3
# GSM435875           None        8140/3
# GSM435876           None        8140/3
# GSM435877           None        8140/3
# GSM435878           None        8140/3
# GSM435879           None        8140/3
# GSM435880           None        8140/3
# GSM435881           None        8140/3
# GSM435882           None        8140/3
# GSM435883           None        8140/3
# GSM435884           None        8140/3
#
# [28 rows x 26 columns]

# %%
clinical_luad=pd.concat([gse72904_clinical,consortium_clinical,gse41271_clinical,gse31210_clinical,pnas_clinical,gse11969_clinical,gse20853_clinical,gse13213_clinical,gse32863_clinical,gse26939_clinical,gse10072_clinical,gse12667_clinical,gse1037_2088_clinical,gse29016_clinical,nm_clinical,gse5843_clinical,gse20875_clinical,gse2514_clinical,gse17475_clinical,tcga_luad_clinical],axis=0)

# %%
clinical_luad
# Out:
# 0                            Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status  \
# Sam_Name
# GSM1854797                            F      88     None               None
# GSM1854798                            F      70        1                  1
# GSM1854799                            F      59        1                  1
# GSM1854800                            M      57        1               None
# GSM1854801                            F      72        1                  4
# ...                                 ...     ...      ...                ...
# TCGA.NJ.A55O.01A.11R.A262.07          F      56        1                  3
# TCGA.NJ.A55R.01A.11R.A262.07          M      67        1                  3
# TCGA.NJ.A7XG.01A.12R.A39D.07          M      49        2                  3
# TCGA.O1.A52J.01A.11R.A262.07          F      74        1                  3
# GSM1854801                                    None                 0
# ...                                            ...               ...
# TCGA.NJ.A55O.01A.11R.A262.07                     0              None
# TCGA.NJ.A55R.01A.11R.A262.07                     0              None
# TCGA.NJ.A7XG.01A.12R.A39D.07                  None              None
# TCGA.O1.A52J.01A.11R.A262.07                     0              None
# TCGA.S2.AA1A.01A.12R.A39D.07                     0              None
#
# 0                            Pat_STK11_mutation Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM1854797                                    0           None        8140/3
# GSM1854798                                    0           None        8140/3
# GSM1854799                                    0           None        8140/3
# GSM1854800                                    0           None        8140/3
# GSM1854801                                    0           None        8140/3
# ...                                         ...            ...           ...
# TCGA.NJ.A55O.01A.11R.A262.07               None             UR        8140/3
# TCGA.NJ.A55R.01A.11R.A262.07               None             UL        8140/3
# TCGA.NJ.A7XG.01A.12R.A39D.07               None             UL        8140/3
# TCGA.O1.A52J.01A.11R.A262.07               None             LL        8140/3
# TCGA.S2.AA1A.01A.12R.A39D.07               None             UR        8140/3
#
# [3218 rows x 26 columns]

# %%
clinical_nsclc=pd.concat([gse1987_clinical,gse4573_clinical,gse8894_clinical,gse9971_clinical,gse10245_clinical,gse11117_clinical,gse14814_clinical,gse16534_clinical,gse18842_clinical,gse19188_clinical,gse19804_clinical,gse25326_clinical,gse28571_clinical,gse37745_clinical,gse42127_clinical,gse43458_clinical,gse50081_clinical],axis=0)

# %%
clinical_nsclc
# Out:
# 0          Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM34988            F    None     None               None               None
# GSM34989            M    None     None               None               None
# GSM34990            M    None     None               None               None
# GSM34991            F    None     None               None               None
# GSM34992            F    None     None               None               None
# ...               ...     ...      ...                ...                ...
# GSM1213845          F      72     None                  3               None
# GSM1213846          M      76     None                  2               None
# GSM1213847          M      76     None                  4                  0
# GSM1213848          F      76     None                  3               None
# GSM1213849          F      60     None                  2               None
#
# 0          Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM34988        11020000               None                  None
# GSM34989        11010000               None                  None
# GSM34990        11020000               None                  None
# GSM34991        11010000               None                  None
# GSM34992        11020000               None                  None
# ...                  ...                ...                   ...
# GSM1213845      11010000                  0                  None
# GSM1213846      11010000                  0                  None
# GSM1213847      11010000                  0                  None
# GSM1213848      11010000                  0                  None
# GSM1213849      11010000                  0                  None
#
# 0          Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                               ...
# GSM34988            None                          NaN  ...         II
# GSM34989            None                          NaN  ...          I
# GSM34990            None                          NaN  ...          I
# GSM34991            None                          NaN  ...         II
# GSM34992            None                          NaN  ...          I
# ...                  ...                          ...  ...        ...
# GSM1213845             0                         14.0  ...         II
# GSM1213846             0                          4.0  ...          I
# GSM1213847             0                         99.0  ...          I
# GSM1213848             0                          1.0  ...         II
# GSM1213849             0                         50.0  ...          I
#
# 0          Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM34988           None      None              None              None
# GSM34989           None      None              None              None
# GSM34990           None      None              None              None
# GSM34991           None      None              None              None
# GSM34992           None      None              None              None
# ...                 ...       ...               ...               ...
# GSM1213845            B      None              None              None
# GSM1213846            B      None              None              None
# GSM1213847            A      None              None              None
# GSM1213848            B      None              None              None
# GSM1213849            A      None              None              None
#
# 0          Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM34988                    None              None               None
# GSM34989                    None              None               None
# GSM34990                    None              None               None
# GSM34991                    None              None               None
# GSM34992                    None              None               None
# ...                          ...               ...                ...
# GSM1213845                  None              None               None
# GSM1213846                  None              None               None
# GSM1213847                  None              None               None
# GSM1213848                  None              None               None
# GSM1213849                  None              None               None
#
# 0          Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM34988             None        8070/3
# GSM34989             None        8140/3
# GSM34990             None        8070/3
# GSM34991             None        8140/3
# GSM34992             None        8070/3
# ...                   ...           ...
# GSM1213845           None        8140/3
# GSM1213846           None        8140/3
# GSM1213847           None        8140/3
# GSM1213848           None        8140/3
# GSM1213849           None        8140/3
#
# [1668 rows x 26 columns]

# %%
clinical_lusc=pd.concat([gse5828_clinical,gse12472_clinical,gse17710_clinical,gse23822_clinical,gse74777_clinical],axis=0)

# %%
clinical_lusc
# Out:
# 0          Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM115459           M      72     None                  2                 11
# GSM115460           M      68     None                  2                 40
# GSM115461           F      65     None                  3                135
# GSM115462           F      74     None                  3                 38
# GSM115463           M      70     None                  3                 57
# ...               ...     ...      ...                ...                ...
# GSM1933069          M      65     None                  3                 27
# GSM1933070          M      67     None                  2                 47
# GSM1933071          M      70     None                  2                 77
# GSM1933072          M      63     None                  2                 43
# GSM1933073          M      80     None                  3                 50
#
# 0          Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM115459       11020000               None                     0
# GSM115460       11020000               None                     0
# GSM115461       11020000               None                     0
# GSM115462       11020000               None                     0
# GSM115463       11020000               None                     0
# ...                  ...                ...                   ...
# GSM1933069      11020000               None                     0
# GSM1933070      11020000               None                     0
# GSM1933071      11020000               None                     0
# GSM1933072      11020000               None                     0
# GSM1933073      11020000               None                     0
#
# 0          Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                               ...
# GSM115459           None                         61.0  ...          I
# GSM115460           None                        154.0  ...          I
# GSM115461           None                        112.0  ...          I
# GSM115462           None                        191.0  ...          I
# GSM115463           None                        126.0  ...          I
# ...                  ...                          ...  ...        ...
# GSM1933069          None                        155.0  ...          I
# GSM1933070          None                        136.0  ...          I
# GSM1933071          None                        101.0  ...          I
# GSM1933072          None                          9.0  ...         II
# GSM1933073          None                         94.0  ...          I
#
# 0          Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM115459             B         1              None              None
# GSM115460             A         1              None              None
# GSM115461             B         2              None              None
# GSM115462             A         2              None              None
# GSM115463             B         1              None              None
# ...                 ...       ...               ...               ...
# GSM1933069            A      None              None              None
# GSM1933070            A      None              None              None
# GSM1933071            B      None              None              None
# GSM1933072            A      None              None              None
# GSM1933073            A      None              None              None
#
# 0          Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM115459                   None              None               None
# GSM115460                   None              None               None
# GSM115461                   None              None               None
# GSM115462                   None              None               None
# GSM115463                   None              None               None
# ...                          ...               ...                ...
# GSM1933069                  None              None               None
# GSM1933070                  None              None               None
# GSM1933071                  None              None               None
# GSM1933072                  None              None               None
# GSM1933073                  None              None               None
#
# 0          Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM115459              LL        8070/3
# GSM115460              UL        8070/3
# GSM115461              LR        8070/3
# GSM115462              LR        8070/3
# GSM115463              UL        8070/3
# ...                   ...           ...
# GSM1933069           None        8070/3
# GSM1933070           None        8070/3
# GSM1933071           None        8070/3
# GSM1933072           None        8070/3
# GSM1933073           None        8070/3
#
# [336 rows x 26 columns]

# %%
clinical_all=pd.concat([clinical_luad,clinical_nsclc,clinical_lusc],axis=0)

# %%
clinical_all
# Out:
# 0          Pat_Gender Pat_Age Pat_Race Pat_Smoking_Status Pat_Packs_Per_Year  \
# Sam_Name
# GSM1854797          F      88     None               None               None
# GSM1854798          F      70        1                  1               None
# GSM1854799          F      59        1                  1               None
# GSM1854800          M      57        1               None               None
# GSM1854801          F      72        1                  4                  0
# ...               ...     ...      ...                ...                ...
# GSM1933069          M      65     None                  3                 27
# GSM1933070          M      67     None                  2                 47
# GSM1933071          M      70     None                  2                 77
# GSM1933072          M      63     None                  2                 43
# GSM1933073          M      80     None                  3                 50
#
# 0          Pat_Histology Pat_Adjuvant_Chemo Pat_Neoadjuvant_Chemo  \
# Sam_Name
# GSM1854797      11010000               None                  None
# GSM1854798      11010000               None                  None
# GSM1854799      11010000               None                  None
# GSM1854800      11010000               None                  None
# GSM1854801      11010000               None                  None
# ...                  ...                ...                   ...
# GSM1933069      11020000               None                     0
# GSM1933070      11020000               None                     0
# GSM1933071      11020000               None                     0
# GSM1933072      11020000               None                     0
# GSM1933073      11020000               None                     0
#
# 0          Pat_Radiation  Pat_Overall_Survival_Months  ...  Pat_Stage  \
# Sam_Name                                               ...
# GSM1854797          None                          NaN  ...       None
# GSM1854798          None                         42.0  ...         IV
# GSM1854799          None                         35.0  ...         II
# GSM1854800          None                         34.0  ...          I
# GSM1854801          None                         30.0  ...          I
# ...                  ...                          ...  ...        ...
# GSM1933069          None                        155.0  ...          I
# GSM1933070          None                        136.0  ...          I
# GSM1933071          None                        101.0  ...          I
# GSM1933072          None                          9.0  ...         II
# GSM1933073          None                         94.0  ...          I
#
# 0          Pat_Substage Pat_Grade Pat_EGFR_mutation Pat_KRAS_mutation  \
# Sam_Name
# GSM1854797         None      None                 1                 0
# GSM1854798         None      None                 0                 0
# GSM1854799            B      None                 0                 0
# GSM1854800            B      None                 0                 0
# GSM1854801            B      None                 0                 0
# ...                 ...       ...               ...               ...
# GSM1933069            A      None              None              None
# GSM1933070            A      None              None              None
# GSM1933071            B      None              None              None
# GSM1933072            A      None              None              None
# GSM1933073            A      None              None              None
#
# 0          Pat_ALK_translocation Pat_TP53_mutation Pat_STK11_mutation  \
# Sam_Name
# GSM1854797                  None                 1                  0
# GSM1854798                  None                 0                  0
# GSM1854799                  None                 0                  0
# GSM1854800                  None                 1                  0
# GSM1854801                  None                 0                  0
# ...                          ...               ...                ...
# GSM1933069                  None              None               None
# GSM1933070                  None              None               None
# GSM1933071                  None              None               None
# GSM1933072                  None              None               None
# GSM1933073                  None              None               None
#
# 0          Pat_Tumor_Site Pat_ICDO_code
# Sam_Name
# GSM1854797           None        8140/3
# GSM1854798           None        8140/3
# GSM1854799           None        8140/3
# GSM1854800           None        8140/3
# GSM1854801           None        8140/3
# ...                   ...           ...
# GSM1933069           None        8070/3
# GSM1933070           None        8070/3
# GSM1933071           None        8070/3
# GSM1933072           None        8070/3
# GSM1933073           None        8070/3
#
# [5222 rows x 26 columns]

# %%
# %%time
with pd.HDFStore('data/LUAD/clinical.h5','w') as store:
    store['clinical_all']=clinical_all
    store['clinical_luad']=clinical_luad
    store['clinical_nsclc']=clinical_nsclc
    store['clinical_lusc']=clinical_lusc
# Out:
# CPU times: total: 31.2 ms
# Wall time: 36 ms
# <timed exec>:2: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block1_values] [items->Index(['Pat_Gender', 'Pat_Age', 'Pat_Race', 'Pat_Smoking_Status',
#        'Pat_Packs_Per_Year', 'Pat_Histology', 'Pat_Adjuvant_Chemo',
#        'Pat_Neoadjuvant_Chemo', 'Pat_Radiation', 'Pat_Time_To_Recurrence',
#        'Pat_Recurrence', 'Pat_T', 'Pat_N', 'Pat_M', 'Pat_Stage',
#        'Pat_Substage', 'Pat_Grade', 'Pat_EGFR_mutation', 'Pat_KRAS_mutation',
#        'Pat_ALK_translocation', 'Pat_TP53_mutation', 'Pat_STK11_mutation',
#        'Pat_Tumor_Site', 'Pat_ICDO_code'],
#       dtype='object', name=0)]
#
# <timed exec>:3: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block1_values] [items->Index(['Pat_Gender', 'Pat_Age', 'Pat_Race', 'Pat_Smoking_Status',
#        'Pat_Packs_Per_Year', 'Pat_Histology', 'Pat_Adjuvant_Chemo',
#        'Pat_Neoadjuvant_Chemo', 'Pat_Radiation', 'Pat_Time_To_Recurrence',
#        'Pat_Recurrence', 'Pat_T', 'Pat_N', 'Pat_M', 'Pat_Stage',
#        'Pat_Substage', 'Pat_Grade', 'Pat_EGFR_mutation', 'Pat_KRAS_mutation',
#        'Pat_ALK_translocation', 'Pat_TP53_mutation', 'Pat_STK11_mutation',
#        'Pat_Tumor_Site', 'Pat_ICDO_code'],
#       dtype='object', name=0)]
#
# <timed exec>:4: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block1_values] [items->Index(['Pat_Gender', 'Pat_Age', 'Pat_Race', 'Pat_Smoking_Status',
#        'Pat_Packs_Per_Year', 'Pat_Histology', 'Pat_Adjuvant_Chemo',
#        'Pat_Neoadjuvant_Chemo', 'Pat_Radiation', 'Pat_Time_To_Recurrence',
#        'Pat_Recurrence', 'Pat_T', 'Pat_N', 'Pat_M', 'Pat_Stage',
#        'Pat_Substage', 'Pat_Grade', 'Pat_EGFR_mutation', 'Pat_KRAS_mutation',
#        'Pat_ALK_translocation', 'Pat_TP53_mutation', 'Pat_STK11_mutation',
#        'Pat_Tumor_Site', 'Pat_ICDO_code'],
#       dtype='object', name=0)]
#
# <timed exec>:5: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block1_values] [items->Index(['Pat_Gender', 'Pat_Age', 'Pat_Race', 'Pat_Smoking_Status',
#        'Pat_Packs_Per_Year', 'Pat_Histology', 'Pat_Adjuvant_Chemo',
#        'Pat_Neoadjuvant_Chemo', 'Pat_Radiation', 'Pat_Time_To_Recurrence',
#        'Pat_Recurrence', 'Pat_T', 'Pat_N', 'Pat_M', 'Pat_Stage',
#        'Pat_Substage', 'Pat_Grade', 'Pat_EGFR_mutation', 'Pat_KRAS_mutation',
#        'Pat_ALK_translocation', 'Pat_TP53_mutation', 'Pat_STK11_mutation',
#        'Pat_Tumor_Site', 'Pat_ICDO_code'],
#       dtype='object', name=0)]

# %% [markdown]
# ## LUSC LABEL

# %% [markdown]
# ## NSCLC LABEL
